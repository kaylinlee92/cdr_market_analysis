# %%
#!{sys.executable} -m pip install geopandas
#!conda install --yes --prefix {sys.prefix} geopandas
# %matplotlib inline
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
from scipy import integrate
import seaborn as sns
import itertools
#from IAM_region_mapping import mappingDict
import json

# %%
## Parameters

# The gas we want to extract from the historical data

# gas = 'CO2'
gas = 'Kyoto Gases'

# Choose years for analysis

beginning_historical_data = 1850
beginning_pop_hist_data = 1960
end_historical_data = 2015
beginning_modelled_data = 2020
end_modelled_data = 2100
time_laps_model = 10
year_for_equity_calculation1 = 2050
year_for_equity_calculation2 = 2100

date_cumulative_beginning = 1990  # note that this should be after 1960 (the start of the population data)



# Group that are in the extracted historical data, but that are not countries

non_countries = ['ANNEXI', 'NONANNEXI', 'AOSIS', 'BASIC', 'EU28', 'LDC', 'UMBRELLA', 'EARTH']



#Variables of interest

var_image={'Emissions|CO2': 'Total_CO2',
       'Emissions|CO2|Carbon Capture and Storage|Biomass': 'BECCS',
       'Emissions|CO2|Land Use|Carbon Sequestration': 'LANDCDR',
          'Emissions|Kyoto Gases': 'Total_GHG',
          'Investment|Energy Supply|Electricity|Non-fossil|Biomass|w/ CCS':'BECCS_Investments',
          'Price|Carbon':'Carbon_Price'}
var_remind={'Emissions|CO2': 'Total_CO2',
            'Emissions|CO2|Carbon Capture and Storage|Biomass': 'BECCS',
            'Emissions|CO2|Land Use|Negative': 'LANDCDR',
           'Emissions|Kyoto Gases': 'Total_GHG',
           'Investment|Energy Supply|Electricity|Non-fossil|Biomass|w/ CCS':'BECCS_Investments',
           'Price|Carbon':'Carbon_Price'}
var_message={'Emissions|CO2': 'Total_CO2',
            'Carbon Sequestration|CCS|Biomass': 'BECCS',
            'Carbon Sequestration|Land Use': 'LANDCDR',
            'Emissions|Kyoto Gases': 'Total_GHG',
            'Investment|Energy Supply|Electricity|Biomass|w/ CCS':'BECCS_Investments',
            'Price|Carbon':'Carbon_Price'}

variable_names = ['Emissions|Kyoto Gases','Carbon Sequestration|Land Use','Carbon Sequestration|CCS|Biomass',
                  'Emissions|CO2|Carbon Capture and Storage|Biomass', 'Emissions|CO2|Land Use|Carbon Sequestration', 
                  'Emissions|CO2|Land Use|Negative', 'Investment|Energy Supply|Electricity|Biomass|w/ CCS', 'Price|Carbon']

# Paths
# data_path = "/Users/Broccolee/Google Drive/Grad School/TU BERLIN/Negative Emissions & Carbon Markets/Data/"
data_path = "/Users/kaylinlee/Desktop/KL_ISIpedia/Thesis/Code/Data/"
plot_path = "/Users/kaylinlee/Desktop/KL_ISIpedia/Thesis/Code/Plots/"

# %%
#Historical Population Data + Emission Data

pop_hist_file = "WDI2016_population_data.csv"
pop_data_hist = pd.read_csv(data_path+'WDI2016_population_data.csv', sep = ",",index_col=0)  #pop in million

primap_in = pd.read_csv(data_path + 'PRIMAP-hist_v2.0_11-Dec-2018.csv')

FAO_data = pd.read_excel(data_path + 'FAO_Emissions_Land_Use_Land_Use_Total_E_All_Data_NOFLAG.xlsx')

#print(pop_hist_file)
#print(primap_in)

# %%
# MESSAGE model

message_path = data_path + "MESSAGE_GLOBIOM/"

model_name_message = 'MESSAGE'

df_message = pd.read_csv(message_path + "ipccsr15_test_dbsnapshot.csv", sep = ";")

scenario_names_message = ['SSP1-19', 'SSP2-19', 'SSP1-26', 'LowEnergyDemand', 'ADVANCE_2020_WB2C']


# NAM without USA
# CPA without CHN & HKG
# SAS without IND
regions_names_message = {
 "R11_SAS": ["AFG", "BGD", "BTN", "LKA", "MDV", "NPL", "PAK"], 
 "R11_EEU": ["ALB", "BGR", "BIH", "CZE", "EST", "HRV", "HUN", "LTU", "LVA", "MKD", "POL", "ROU", "SVN", "SVK", "SRB", "MNE"], 
 "R11_MEA": ["ARE", "BHR", "DZA", "EGY", "IRN", "IRQ", "ISR", "JOR", "KWT", "LBN", "LBY", "MAR", "OMN", "QAT", "SAU", "SDN", "SYR", "TUN", "YEM"], 
 "R11_PAS": ["ASM", "BRN", "FJI", "IDN", "KIR", "KOR", "MMR", "MYS", "NCL", "PHL", "PNG", "PYF", "SGP", "SLB", "THA", "TON", "TWN", "VUT", "WSM", "TLS"], 
 "R11_WEU": ["AND", "AUT", "BEL", "CHE", "CYP", "DEU", "DNK", "ESP", "FIN", "FRA", "FRO", "GBR", "GIB", "GRC", "GRL", "IMN", "IRL", "ISL", "ITA", "LIE", "LUX", "MCO", "MLT", "NLD", "NOR", "PRT", "SWE", "TUR"], 
 "R11_AFR": ["AGO", "BDI", "BEN", "BFA", "BWA", "CAF", "CIV", "CMR", "COG", "COM", "CPV", "DJI", "ERI", "ETH", "GAB", "GHA", "GIN", "GMB", "GNB", "GNQ", "IOT", "KEN", "LBR", "LSO", "MDG", "MLI", "MOZ", "MRT", "MUS", "MWI", "NAM", "NER", "NGA", "REU", "RWA", "SEN", "SHN", "SLE", "SOM", "STP", "SWZ", "SYC", "TCD", "TGO", "TZA", "UGA", "ZAF", "ZMB", "ZWE", "COG", "COD"], 
 "R11_LAM": ["ARG", "ATG", "BHS", "BLZ", "BMU", "BOL", "BRA", "CHL", "COL", "CRI", "CUB", "DMA", "DOM", "ECU", "GLP", "GRD", "GTM", "GUY", "HND", "HTI", "JAM", "KNA", "MEX", "MTQ", "NIC", "PAN", "PER", "PRY", "SLV", "SUR", "TTO", "URY", "VCT", "VEN"], 
 "R11_FSU": ["ARM", "AZE", "BLR", "GEO", "KAZ", "KGZ", "MDA", "RUS", "TJK", "TKM", "UKR", "UZB"], 
 "R11_PAO": ["AUS", "JPN", "NZL"], 
 "R11_CPA": ["KHM", "LAO", "MNG", "PRK", "VNM"], 
 "R11_NAM": ["CAN", "GUM", "PRI", "VGB"],
 "USA": ['USA'],
 "CHN": ['CHN', "HKG"],
 "IND": ['IND'],
 "EU" : ["ALB", "BGR", "BIH", "CZE", "EST", "HRV", "HUN", "LTU", "LVA", "MKD", "POL", "ROU", "SVN", "SVK", "SRB", "MNE", "AND", "AUT", "BEL", "CHE", "CYP", "DEU", "DNK", "ESP", "FIN", "FRA", "FRO", "GBR", "GIB", "GRC", "GRL", "IMN", "IRL", "ISL", "ITA", "LIE", "LUX", "MCO", "MLT", "NLD", "NOR", "PRT", "SWE", "TUR"],
 "World": ['EARTH', 'WLD']
}

# %%
## Getting MESSAGE data format to match the other models
df_message = df_message.rename(columns={"MODEL": "Model", "SCENARIO": "Scenario", "REGION": "Region", "VARIABLE":"Variable", "UNIT": "Unit", "YEAR": 'Year', "VALUE": 'Value'})

df_message_copy = df_message.copy()
# df_message_copy = df_message_copy.loc[df_message_copy.Variable.isin(variable_names)]
df_pivot = pd.pivot_table(df_message_copy, values='Value', index = ['Scenario', 'Region', 'Variable', 'Model', 'Unit'], columns=['Year'], aggfunc = np.sum)
df_pivot_res = df_pivot.reset_index()
df_message = pd.DataFrame(df_pivot_res)
df_message = df_message.drop(columns = [2000])
df_message.to_csv(data_path + 'message_help', index=False) 
df_message = pd.read_csv(data_path + 'message_help')
df_message= df_message[df_message.Region != 'R5ASIA']
df_message= df_message[df_message.Region != 'R5LAM']
df_message= df_message[df_message.Region != 'R5MAF']
df_message= df_message[df_message.Region != 'R5OECD90+EU']
df_message= df_message[df_message.Region != 'R5REF']
df_message= df_message[df_message.Region != 'R11_NAM']
df_message= df_message[df_message.Region != 'R11_CPA']
df_message= df_message[df_message.Region != 'R11_SAS']
df_message= df_message[df_message.Region != 'R11_WEU']
df_message= df_message[df_message.Region != 'R11_EEU']

df_message.rename(columns={'2005': 2005,
                          '2010': 2010,
                          '2020': 2020,
                          '2030': 2030,
                          '2040': 2040,
                          '2050': 2050,
                          '2060': 2060,
                          '2070': 2070,
                          '2080': 2080,
                          '2090': 2090,
                          '2100': 2100}, 
                 inplace=True)
df_message = df_message[['Model', 'Scenario', 'Region', 'Variable', 'Unit', 2005, 2010, 2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100]]
df_message
# Out:
#                      Model                Scenario   Region  \
# 0      MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 1      MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 2      MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 3      MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 4      MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 5      MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 6      MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 7      MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 8      MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 9      MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 10     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 11     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 12     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 13     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 14     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 15     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 16     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 17     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 18     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 19     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 20     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 21     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 22     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 23     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 24     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 25     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 26     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 27     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 28     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# 29     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN
# ...                    ...                     ...      ...
# 81097  MESSAGE-GLOBIOM 1.0           SSP3-Baseline       EU
# 81098  MESSAGE-GLOBIOM 1.0           SSP3-Baseline       EU
# 81099  MESSAGE-GLOBIOM 1.0           SSP3-Baseline       EU
# 81100  MESSAGE-GLOBIOM 1.0           SSP3-Baseline      IND
# 81101  MESSAGE-GLOBIOM 1.0           SSP3-Baseline      IND
# 81102  MESSAGE-GLOBIOM 1.0           SSP3-Baseline      IND
# 81103  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_AFR
# 81104  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_AFR
# 81105  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_AFR
# 81112  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_FSU
# 81113  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_FSU
# 81114  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_FSU
# 81115  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_LAM
# 81116  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_LAM
# 81117  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_LAM
# 81118  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_MEA
# 81119  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_MEA
# 81120  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_MEA
# 81124  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_PAO
# 81125  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_PAO
# 81126  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_PAO
# 81127  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_PAS
# 81128  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_PAS
# 81129  MESSAGE-GLOBIOM 1.0           SSP3-Baseline  R11_PAS
# 81156  MESSAGE-GLOBIOM 1.0           SSP3-Baseline      USA
# 81157  MESSAGE-GLOBIOM 1.0           SSP3-Baseline      USA
# 81158  MESSAGE-GLOBIOM 1.0           SSP3-Baseline      USA
# 81159  MESSAGE-GLOBIOM 1.0           SSP3-Baseline    World
# 81160  MESSAGE-GLOBIOM 1.0           SSP3-Baseline    World
# 81161  MESSAGE-GLOBIOM 1.0           SSP3-Baseline    World
#
#                                                 Variable                Unit  \
# 0                           Capacity|Electricity|Biomass                  GW
# 1                              Capacity|Electricity|Coal                  GW
# 2                               Capacity|Electricity|Gas                  GW
# 3                        Capacity|Electricity|Geothermal                  GW
# 4                             Capacity|Electricity|Hydro                  GW
# 5                           Capacity|Electricity|Nuclear                  GW
# 6                               Capacity|Electricity|Oil                  GW
# 7                             Capacity|Electricity|Solar                  GW
# 8                         Capacity|Electricity|Solar|CSP                  GW
# 9                          Capacity|Electricity|Solar|PV                  GW
# 10                             Capacity|Electricity|Wind                  GW
# 11                    Capacity|Electricity|Wind|Offshore                  GW
# 12                     Capacity|Electricity|Wind|Onshore                  GW
# 13                              Carbon Sequestration|CCS           Mt CO2/yr
# 14                      Carbon Sequestration|CCS|Biomass           Mt CO2/yr
# 15        Carbon Sequestration|CCS|Biomass|Energy|Supply           Mt CO2/yr
# 16     Carbon Sequestration|CCS|Biomass|Energy|Supply...           Mt CO2/yr
# 17     Carbon Sequestration|CCS|Biomass|Energy|Supply...           Mt CO2/yr
# 18     Carbon Sequestration|CCS|Biomass|Energy|Supply...           Mt CO2/yr
# 19                       Carbon Sequestration|CCS|Fossil           Mt CO2/yr
# 20         Carbon Sequestration|CCS|Fossil|Energy|Supply           Mt CO2/yr
# 21     Carbon Sequestration|CCS|Fossil|Energy|Supply|...           Mt CO2/yr
# 22     Carbon Sequestration|CCS|Fossil|Energy|Supply|...           Mt CO2/yr
# 23     Carbon Sequestration|CCS|Fossil|Energy|Supply|...           Mt CO2/yr
# 24                                           Consumption  billion US$2010/yr
# 25                                          Emissions|BC            Mt BC/yr
# 26                                         Emissions|CH4           Mt CH4/yr
# 27                                   Emissions|CH4|AFOLU           Mt CH4/yr
# 28                  Emissions|CH4|Energy|Demand|Industry           Mt CH4/yr
# 29     Emissions|CH4|Energy|Demand|Residential and Co...           Mt CH4/yr
# ...                                                  ...                 ...
# 81097                                        Food Demand        kcal/cap/day
# 81098                                  Food Demand|Crops        kcal/cap/day
# 81099                              Food Demand|Livestock        kcal/cap/day
# 81100                                        Food Demand        kcal/cap/day
# 81101                                  Food Demand|Crops        kcal/cap/day
# 81102                              Food Demand|Livestock        kcal/cap/day
# 81103                                        Food Demand        kcal/cap/day
# 81104                                  Food Demand|Crops        kcal/cap/day
# 81105                              Food Demand|Livestock        kcal/cap/day
# 81112                                        Food Demand        kcal/cap/day
# 81113                                  Food Demand|Crops        kcal/cap/day
# 81114                              Food Demand|Livestock        kcal/cap/day
# 81115                                        Food Demand        kcal/cap/day
# 81116                                  Food Demand|Crops        kcal/cap/day
# 81117                              Food Demand|Livestock        kcal/cap/day
# 81118                                        Food Demand        kcal/cap/day
# 81119                                  Food Demand|Crops        kcal/cap/day
# 81120                              Food Demand|Livestock        kcal/cap/day
# 81124                                        Food Demand        kcal/cap/day
# 81125                                  Food Demand|Crops        kcal/cap/day
# 81126                              Food Demand|Livestock        kcal/cap/day
# 81127                                        Food Demand        kcal/cap/day
# 81128                                  Food Demand|Crops        kcal/cap/day
# 81129                              Food Demand|Livestock        kcal/cap/day
# 81156                                        Food Demand        kcal/cap/day
# 81157                                  Food Demand|Crops        kcal/cap/day
# 81158                              Food Demand|Livestock        kcal/cap/day
# 81159                                        Food Demand        kcal/cap/day
# 81160                                  Food Demand|Crops        kcal/cap/day
# 81161                              Food Demand|Livestock        kcal/cap/day
#
#               2005         2010         2020          2030          2040  \
# 0         0.407790     0.440720     0.275850      5.123790      5.491130
# 1       403.117530   755.858960   972.012160    778.129030    308.549880
# 2         6.332510    17.208040    33.967230     57.190280     61.426300
# 3         0.000000     0.045000     0.045000      0.780510      1.589660
# 4       109.416660   270.029450   270.047740    477.742840    486.071410
# 5         6.587000     9.437000    82.949900    189.328700    426.559600
# 6        10.424220     8.406560     7.436220      1.600280      0.000000
# 7         0.000000     1.200000     9.875790    684.346690   1148.581090
# 8         0.000000     0.000000     0.000000      0.000000      0.000000
# 9         0.000000     1.200000     9.875790    684.346690   1148.581090
# 10        1.249500    72.499500   229.451500    904.665950   2089.562200
# 11        0.000000     0.000000     0.000000     17.531200     17.531200
# 12        1.249500    72.499500   229.451500    887.134750   2072.031000
# 13        0.000000     0.000000     9.906820    291.716883    648.473173
# 14        0.000000     0.000000     0.000000      5.736683     68.367787
# 15        0.000000     0.000000     0.000000      5.736683     68.367787
# 16        0.000000     0.000000     0.000000      0.000000     28.001270
# 17        0.000000     0.000000     0.000000      0.000000     15.156277
# 18        0.000000     0.000000     0.000000      5.736683     25.210240
# 81129    407.563034    427.741093    446.951385    455.854888    467.328938
# 81156   3745.914680   3751.072106   3754.590935   3756.128830   3759.198722
# 81157   2741.643943   2744.515318   2747.017857   2747.804598   2749.908356
# 81158   1004.270736   1006.556788   1007.573079   1008.324233   1009.290366
# 81159   2935.974259   2951.756317   2971.060065   2982.646709   3001.819316
# 81160   2420.243731   2442.861492   2466.657992   2480.792355   2502.240696
# 81161    515.730528    508.894826    504.402073    501.854354    499.578620
#
#                2100
# 0         23.026080
# 1          0.000000
# 2        307.358150
# 3          8.357140
# 4        486.607160
# 5        360.225300
# 6          0.000000
# 7       2600.949590
# 8          6.603390
# 9       2594.346200
# 10      2813.497100
# 11       741.466100
# 12      2072.031000
# 13      1784.124430
# 14      1539.216800
# 15      1539.216800
# 16         0.000000
# 17         0.000000
# 18      1539.216800
# 19         0.000000
# 20         0.000000
# 21         0.000000
# 22         0.000000
# 23         0.000000
# 24     65644.700000
# 25         0.022981
# 26         9.285281
# 27         7.409480
# 28         0.000000
# 29         0.000000
# ...             ...
# 81097   6739.608989
# 81098   4841.249470
# 81099   1898.359519
# 81100   2933.835114
# 81101   2482.271562
# 81102    451.563552
# 81103   2824.604470
# 81104   2603.939382
# 81105    220.665088
# 81112   3234.317528
# 81113   2336.883316
# 81114    897.434212
# 81115   3264.952145
# 81116   2486.383891
# 81117    778.568254
# 81118   2869.985429
# 81119   2477.603365
# 81120    392.382064
# 81124   3217.062824
# 81125   2290.268984
# 81126    926.793840
# 81127   3112.616334
# 81128   2630.877853
# 81129    481.738482
# 81156   3764.432251
# 81157   2752.902720
# 81158   1011.529531
# 81159   3021.043225
# 81160   2522.326402
# 81161    498.716823
#
# [46108 rows x 16 columns]

# %%
print(df_message.loc[(df_message.Region == 'World') & (df_message.Variable == 'Price|Carbon') & (df_message.Scenario == 'SSP1-19')])
print(df_message.loc[(df_message.Region == 'World') & (df_message.Variable == 'Price|Carbon') & (df_message.Scenario == 'LowEnergyDemand')])
# Out:
# Empty DataFrame
# Columns: [Model, Scenario, Region, Variable, Unit, 2005, 2010, 2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100]
# Index: []
#                        Model         Scenario Region      Variable  \
# 52597  MESSAGEix-GLOBIOM 1.0  LowEnergyDemand  World  Price|Carbon
#
#                 Unit  2005  2010      2020       2030        2040        2050  \
# 52597  US$2010/t CO2   0.0   0.0  0.234714  88.917016  119.497034  160.594016
#
#              2060        2070        2080        2090        2100
# 52597  215.824936  290.050665  389.803852  523.863798  704.029113

# %%
# MESSAGE DATA CLEAN-UP for carbon price
df_carbon_price = df_message.loc[(df_message.Variable == 'Price|Carbon')]
#df_carbon_price = df_message.filter(Variable='Price|Carbon', Year=range(2030, 2101, 10))
print(df_carbon_price)

# 2030 carbon price values below 5 
scen_w_invalid_CarbonPrice = df_message.loc[(df_message.Variable == 'Price|Carbon') & 
                                            (df_message[2030] < 5)].Scenario.unique()
print(scen_w_invalid_CarbonPrice)
#print(df_message.Scenario.unique()-scen_w_invalid_CarbonPrice)

# carbon price values are NaN in any time series
#print(df_message.isnull().any(axis=1))
#print(df_carbon_price.apply(lambda x: np.isnan(max(x)), axis=1))
#null_data = df_message.loc[df_message.isnull() ]
#print(null_data)
# Out:
#                        Model                Scenario   Region      Variable  \
# 118      MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      CHN  Price|Carbon
# 307      MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100       EU  Price|Carbon
# 496      MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      IND  Price|Carbon
# 685      MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100  R11_AFR  Price|Carbon
# 1252     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100  R11_FSU  Price|Carbon
# 1441     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100  R11_LAM  Price|Carbon
# 1630     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100  R11_MEA  Price|Carbon
# 2008     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100  R11_PAO  Price|Carbon
# 2197     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100  R11_PAS  Price|Carbon
# 3709     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100      USA  Price|Carbon
# 3956     MESSAGE-GLOBIOM 1.0  ADVANCE_2020_1.5C-2100    World  Price|Carbon
# 4145     MESSAGE-GLOBIOM 1.0      ADVANCE_2020_Med2C      CHN  Price|Carbon
# 4333     MESSAGE-GLOBIOM 1.0      ADVANCE_2020_Med2C       EU  Price|Carbon
# 4521     MESSAGE-GLOBIOM 1.0      ADVANCE_2020_Med2C      IND  Price|Carbon
# 4709     MESSAGE-GLOBIOM 1.0      ADVANCE_2020_Med2C  R11_AFR  Price|Carbon
# 5273     MESSAGE-GLOBIOM 1.0      ADVANCE_2020_Med2C  R11_FSU  Price|Carbon
# 5461     MESSAGE-GLOBIOM 1.0      ADVANCE_2020_Med2C  R11_LAM  Price|Carbon
# 5649     MESSAGE-GLOBIOM 1.0      ADVANCE_2020_Med2C  R11_MEA  Price|Carbon
# 6025     MESSAGE-GLOBIOM 1.0      ADVANCE_2020_Med2C  R11_PAO  Price|Carbon
# 6213     MESSAGE-GLOBIOM 1.0      ADVANCE_2020_Med2C  R11_PAS  Price|Carbon
# 7717     MESSAGE-GLOBIOM 1.0      ADVANCE_2020_Med2C      USA  Price|Carbon
# 7963     MESSAGE-GLOBIOM 1.0      ADVANCE_2020_Med2C    World  Price|Carbon
# 8151     MESSAGE-GLOBIOM 1.0       ADVANCE_2020_WB2C      CHN  Price|Carbon
# 8340     MESSAGE-GLOBIOM 1.0       ADVANCE_2020_WB2C       EU  Price|Carbon
# 8529     MESSAGE-GLOBIOM 1.0       ADVANCE_2020_WB2C      IND  Price|Carbon
# 8718     MESSAGE-GLOBIOM 1.0       ADVANCE_2020_WB2C  R11_AFR  Price|Carbon
# 9285     MESSAGE-GLOBIOM 1.0       ADVANCE_2020_WB2C  R11_FSU  Price|Carbon
# 9474     MESSAGE-GLOBIOM 1.0       ADVANCE_2020_WB2C  R11_LAM  Price|Carbon
# 9663     MESSAGE-GLOBIOM 1.0       ADVANCE_2020_WB2C  R11_MEA  Price|Carbon
# 10041    MESSAGE-GLOBIOM 1.0       ADVANCE_2020_WB2C  R11_PAO  Price|Carbon
# ...                      ...                     ...      ...           ...
# 44869            MESSAGE V.3            GEA_Mix_base      USA  Price|Carbon
# 44878            MESSAGE V.3            GEA_Mix_base    World  Price|Carbon
# 45152  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand      CHN  Price|Carbon
# 45522  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand       EU  Price|Carbon
# 45892  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand      IND  Price|Carbon
# 46262  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand  R11_AFR  Price|Carbon
# 47371  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand  R11_FSU  Price|Carbon
# 47741  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand  R11_LAM  Price|Carbon
# 48111  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand  R11_MEA  Price|Carbon
# 48851  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand  R11_PAO  Price|Carbon
# 49221  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand  R11_PAS  Price|Carbon
# 52181  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand      USA  Price|Carbon
# 52597  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand    World  Price|Carbon
# 52906    MESSAGE-GLOBIOM 1.0                 SSP1-19      CHN  Price|Carbon
# 53184    MESSAGE-GLOBIOM 1.0                 SSP1-19       EU  Price|Carbon
# 53462    MESSAGE-GLOBIOM 1.0                 SSP1-19      IND  Price|Carbon
# 53740    MESSAGE-GLOBIOM 1.0                 SSP1-19  R11_AFR  Price|Carbon
# 54574    MESSAGE-GLOBIOM 1.0                 SSP1-19  R11_FSU  Price|Carbon
# 54852    MESSAGE-GLOBIOM 1.0                 SSP1-19  R11_LAM  Price|Carbon
# 55130    MESSAGE-GLOBIOM 1.0                 SSP1-19  R11_MEA  Price|Carbon
# 55686    MESSAGE-GLOBIOM 1.0                 SSP1-19  R11_PAO  Price|Carbon
# 55964    MESSAGE-GLOBIOM 1.0                 SSP1-19  R11_PAS  Price|Carbon
# 58188    MESSAGE-GLOBIOM 1.0                 SSP1-19      USA  Price|Carbon
# 80173    MESSAGE-GLOBIOM 1.0                 SSP2-19      USA  Price|Carbon
# 80196    MESSAGE-GLOBIOM 1.0                 SSP2-19    World  Price|Carbon
# 80390    MESSAGE-GLOBIOM 1.0                 SSP2-26      CHN  Price|Carbon
# 80423    MESSAGE-GLOBIOM 1.0                 SSP2-26       EU  Price|Carbon
# 80462    MESSAGE-GLOBIOM 1.0                 SSP2-26      IND  Price|Carbon
# 80551    MESSAGE-GLOBIOM 1.0                 SSP2-26  R11_LAM  Price|Carbon
# 80563    MESSAGE-GLOBIOM 1.0                 SSP2-26  R11_MEA  Price|Carbon
#
#                 Unit        2005        2010        2020        2030  \
# 118    US$2010/t CO2   73.247328  105.611528  172.030056  280.218840
# 307    US$2010/t CO2  146.494656  211.223056  344.060112  560.437680
# 496    US$2010/t CO2   73.247328  105.611528  172.030056  280.218840
# 685    US$2010/t CO2   73.247328  105.611528  172.030056  280.218840
# 1252   US$2010/t CO2   73.247328  105.611528  172.030056  280.218840
# 1441   US$2010/t CO2   73.247328  105.611528  172.030056  280.218840
# 1630   US$2010/t CO2   73.247328  105.611528  172.030056  280.218840
# 80173   3375.244059   5497.916908
# 80196   3375.244059   5497.916908
# 80390    655.989906   1068.538438
# 80423   1311.979812   2137.076876
# 80462    655.989906   1068.538438
# 80551    655.989906   1068.538438
# 80563    655.989906   1068.538438
#
# [451 rows x 16 columns]
# ['ADVANCE_INDC' 'ADVANCE_NoPolicy' 'ADVANCE_Reference' 'CD-LINKS_INDCi'
#  'CD-LINKS_NDC2030i_1000' 'CD-LINKS_NPi' 'EMF30_BCOC-EndU'
#  'EMF30_Baseline' 'EMF30_CH4-Only' 'EMF30_D_BCOC-Red' 'EMF30_SLCF'
#  'EMF30_Slower-Action' 'EMF30_Slower-Action+SLCF' 'EMF33_Baseline'
#  'GEA_Eff_base' 'GEA_Mix_base']

# %%
#REMIND Model

remind_path = data_path + "REMIND/SSPs/"
model_name_remind = 'REMIND'


remind_SSP1_19 = pd.read_csv(remind_path + "SSP1-19-SPA1-V17_corr.mif", sep = ";")
remind_SSP1_26 = pd.read_csv(remind_path + "SSP1-26-SPA1-V17_corr.mif", sep = ";")
remind_SSP2_19 = pd.read_csv(remind_path + "SSP2-19-SPA2-V17_corr.mif", sep = ";")
remind_SSP2_26 = pd.read_csv(remind_path + "SSP2-26-SPA2-V17_corr.mif", sep = ";")
remind_SSP5_19 = pd.read_csv(remind_path + "SSP5-19-SPA5-V17_corr.mif", sep = ";")
remind_SSP5_26 = pd.read_csv(remind_path + "SSP5-26-SPA5-V17_corr.mif", sep = ";")


regions_names_remind = {
    "ROW": ['ALB', 'AND', 'ATA', 'AUS', 'BIH', 'BLR', 'BVT', 'CAN', 'CHE', 'GGY', 'HMD', 'HRV', 'ISL', 'LIE', 'MAF'
            'MCO', 'MDA', 'MKD', 'MNE', 'NOR', 'NRU', 'NZL', 'SGS', 'SJM', 'SMR', 'SPM', 'SRB', 'TUR', 'UKR', 'VAT',
            'ZAF'], 
    "USA": ['USA', 'PRI'],
    "LAM": ['ABW', 'AIA', 'ARG', 'ATG', 'BES', 'BHS', 'BLM', 'BLZ', 'BMU', 'BOL', 'BRA', 'BRB', 'CHL', 'COL', 'CRI',
            'CUB', 'CUW', 'CYM', 'DMA', 'DOM', 'ECU', 'FLK', 'GLP', 'GRD', 'GTM', 'GUF', 'GUY', 'HND', 'HTI', 'JAM',
            'KNA', 'LCA', 'MEX', 'MSR', 'MTQ', 'NIC', 'PAN', 'PER', 'PRY', 'SLV', 'SUR', 'SXM', 'TCA', 'TTO', 'URY',
            'VCT', 'VEN', 'VGB', 'VIR'],
    "EUR": ['ALA', 'AUT', 'BEL', 'BGR', 'CYP', 'CZE', 'DEU', 'DNK', 'ESP', 'EST', 'FIN', 'FRA', 'FRO', 'GBR', 'GIB',
            'GRC', 'GRL', 'HUN', 'IMN', 'IRL', 'ITA', 'JEY', 'LTU', 'LUX', 'LVA', 'MLT', 'NLD', 'POL', 'PRT', 'ROU',
            'SVK', 'SVN', 'SWE'],
    "AFR": ['AGO', 'BDI', 'BEN', 'BFA', 'BWA', 'CAF', 'CIV', 'CMR', 'COD', 'COG', 'COM', 'CPV', 'DJI', 'ERI', 'ETH', 
            'GAB', 'GHA', 'GIN', 'GMB', 'GNB', 'GNQ', 'KEN', 'LBR', 'LSO', 'MDG', 'MLI', 'MOZ', 'MRT', 'MUS', 'MWI',
            'MYT', 'NAM', 'NER', 'NGA', 'REU', 'RWA', 'SDN', 'SEN', 'SHN', 'SLE', 'SOM', 'SSD', 'STP', 'SWZ', 'SYC',
            'TCD', 'TGO', 'TZA', 'UGA', 'ZMB', 'ZWE'],
    "MEA": ['ARE', 'ARM', 'AZE', 'BHR', 'DZA', 'EGY', 'ESH', 'GEO', 'IRN', 'IRQ', 'ISR', 'JOR', 'KAZ', 'KGZ', 'KWT',
            'LBN', 'LBY', 'MAR', 'OMN', 'PSE', 'QAT', 'SAU', 'SYR', 'TJK', 'TKM', 'TUN', 'UZB', 'YEM'],
    "IND": ['IND'],
    "RUS": ['RUS'],
    "CHN": ['CHN', 'HKG', 'MAC'],
    "JPN": ['JPN'],
    "OAS": ['AFG', 'ASM', 'ATF', 'BGD', 'BRN', 'BTN', 'CCK', 'COK', 'CXR', 'FJI', 'FSM', 'GUM', 'IDN', 'IOT', 'KHM',
            'KIR', 'KOR', 'LAO', 'LKA', 'MDV', 'MHL', 'MMR', 'MNG', 'MNP', 'MYS', 'NCL', 'NFK', 'NIU', 'NPL', 'PAK',
            'PCN', 'PHL', 'PLW', 'PNG', 'PRK', 'PYF', 'SGP', 'SLB', 'THA', 'TKL', 'TLS', 'TON', 'TUV', 'TWN', 'UMI',
            'VNM', 'VUT', 'WLF', 'WSM'],
    "World": ['ALB', 'AND', 'ATA', 'AUS', 'BIH', 'BLR', 'BVT', 'CAN', 'CHE', 'GGY', 'HMD', 'HRV', 'ISL', 'LIE', 'MAF'
            'MCO', 'MDA', 'MKD', 'MNE', 'NOR', 'NRU', 'NZL', 'SGS', 'SJM', 'SMR', 'SPM', 'SRB', 'TUR', 'UKR', 'VAT',
            'ZAF', 'USA', 'PRI', 'ABW', 'AIA', 'ARG', 'ATG', 'BES', 'BHS', 'BLM', 'BLZ', 'BMU', 'BOL', 'BRA', 'BRB',
            'CHL', 'COL', 'CRI', 'CUB', 'CUW', 'CYM', 'DMA', 'DOM', 'ECU', 'FLK', 'GLP', 'GRD', 'GTM', 'GUF', 'GUY', 
            'HND', 'HTI', 'JAM', 'KNA', 'LCA', 'MEX', 'MSR', 'MTQ', 'NIC', 'PAN', 'PER', 'PRY', 'SLV', 'SUR', 'SXM', 
            'TCA', 'TTO', 'URY', 'VCT', 'VEN', 'VGB', 'VIR', 'ALA', 'AUT', 'BEL', 'BGR', 'CYP', 'CZE', 'DEU', 'DNK', 
            'ESP', 'EST', 'FIN', 'FRA', 'FRO', 'GBR', 'GIB', 'GRC', 'GRL', 'HUN', 'IMN', 'IRL', 'ITA', 'JEY', 'LTU', 
            'LUX', 'LVA', 'MLT', 'NLD', 'POL', 'PRT', 'ROU', 'SVK', 'SVN', 'SWE', 'AGO', 'BDI', 'BEN', 'BFA', 'BWA', 
            'CAF', 'CIV', 'CMR', 'COD', 'COG', 'COM', 'CPV', 'DJI', 'ERI', 'ETH', 'GAB', 'GHA', 'GIN', 'GMB', 'GNB', 
            'GNQ', 'KEN', 'LBR', 'LSO', 'MDG', 'MLI', 'MOZ', 'MRT', 'MUS', 'MWI', 'MYT', 'NAM', 'NER', 'NGA', 'REU',
            'RWA', 'SDN', 'SEN', 'SHN', 'SLE', 'SOM', 'SSD', 'STP', 'SWZ', 'SYC', 'TCD', 'TGO', 'TZA', 'UGA', 'ZMB', 
            'ZWE', 'ARE', 'ARM', 'AZE', 'BHR', 'DZA', 'EGY', 'ESH', 'GEO', 'IRN', 'IRQ', 'ISR', 'JOR', 'KAZ', 'KGZ', 
            'KWT', 'LBN', 'LBY', 'MAR', 'OMN', 'PSE', 'QAT', 'SAU', 'SYR', 'TJK', 'TKM', 'TUN', 'UZB', 'YEM', 'IND',
            'RUS', 'CHN', 'HKG', 'MAC', 'JPN', 'AFG', 'ASM', 'ATF', 'BGD', 'BRN', 'BTN', 'CCK', 'COK', 'CXR', 'FJI', 
            'FSM', 'GUM', 'IDN', 'IOT', 'KHM', 'KIR', 'KOR', 'LAO', 'LKA', 'MDV', 'MHL', 'MMR', 'MNG', 'MNP', 'MYS',
            'NCL', 'NFK', 'NIU', 'NPL', 'PAK', 'PCN', 'PHL', 'PLW', 'PNG', 'PRK', 'PYF', 'SGP', 'SLB', 'THA', 'TKL', 
            'TLS', 'TON', 'TUV', 'TWN', 'UMI', 'VNM', 'VUT', 'WLF', 'WSM']
}

# %%
df_remind = remind_SSP1_19.append(remind_SSP2_19, ignore_index = True)
df_remind = df_remind.append(remind_SSP1_26, ignore_index = True)
df_remind = df_remind.append(remind_SSP2_26, ignore_index = True)
df_remind = df_remind.append(remind_SSP5_19, ignore_index = True)
df_remind = df_remind.append(remind_SSP5_26, ignore_index = True)

df_remind['2005'] = df_remind['2005'].apply(pd.to_numeric)
df_remind['2010'] = df_remind['2010'].apply(pd.to_numeric)
df_remind['2020'] = df_remind['2020'].apply(pd.to_numeric)
df_remind['2030'] = df_remind['2030'].apply(pd.to_numeric)
df_remind['2040'] = df_remind['2040'].apply(pd.to_numeric)
df_remind['2050'] = df_remind['2050'].apply(pd.to_numeric)
df_remind['2060'] = df_remind['2060'].apply(pd.to_numeric)
df_remind['2070'] = df_remind['2070'].apply(pd.to_numeric)
df_remind['2080'] = df_remind['2080'].apply(pd.to_numeric)
df_remind['2090'] = df_remind['2090'].apply(pd.to_numeric)
df_remind['2100'] = df_remind['2100'].apply(pd.to_numeric)

df_remind.rename(columns={'2005': 2005,
                          '2010': 2010,
                          '2020': 2020,
                          '2030': 2030,
                          '2040': 2040,
                          '2050': 2050,
                          '2060': 2060,
                          '2070': 2070,
                          '2080': 2080,
                          '2090': 2090,
                          '2100': 2100}, 
                 inplace=True)

print(df_remind)
# Out:
#                Model          Scenario Region  \
# 0      REMIND-MAGPIE  SSP1-19-SPA1-V17    AFR
# 55165  REMIND-MAGPIE  SSP5-26-SPA5-V17    RUS
# 55166  REMIND-MAGPIE  SSP5-26-SPA5-V17    USA
# 55167  REMIND-MAGPIE  SSP5-26-SPA5-V17  World
# 55168  REMIND-MAGPIE  SSP5-26-SPA5-V17    AFR
# 55169  REMIND-MAGPIE  SSP5-26-SPA5-V17    CHN
# 55170  REMIND-MAGPIE  SSP5-26-SPA5-V17    EUR
# 55171  REMIND-MAGPIE  SSP5-26-SPA5-V17    IND
# 55172  REMIND-MAGPIE  SSP5-26-SPA5-V17    JPN
# 55173  REMIND-MAGPIE  SSP5-26-SPA5-V17    LAM
# 55174  REMIND-MAGPIE  SSP5-26-SPA5-V17    MEA
# 55175  REMIND-MAGPIE  SSP5-26-SPA5-V17    OAS
# 55176  REMIND-MAGPIE  SSP5-26-SPA5-V17    ROW
# 55177  REMIND-MAGPIE  SSP5-26-SPA5-V17    RUS
# 55178  REMIND-MAGPIE  SSP5-26-SPA5-V17    USA
# 55179  REMIND-MAGPIE  SSP5-26-SPA5-V17  World
#
#                               Variable       Unit       2005       2010  \
# 0                 Capacity|Electricity         GW    27.7200    36.4500
# 1                 Capacity|Electricity         GW   434.1000   775.4000
# 2                 Capacity|Electricity         GW   638.5000   678.6000
# 3                 Capacity|Electricity         GW   134.7000   176.5000
# 4                 Capacity|Electricity         GW   215.2000   215.9000
# 5                 Capacity|Electricity         GW   266.5000   302.5000
# 6                 Capacity|Electricity         GW   281.8000   308.1000
# 7                 Capacity|Electricity         GW   271.4000   319.6000
# 8                 Capacity|Electricity         GW   350.7000   381.7000
# 9                 Capacity|Electricity         GW   135.7000   158.8000
# 10                Capacity|Electricity         GW   800.3000   801.7000
# 11                Capacity|Electricity         GW  3557.0000  4155.0000
# 12        Capacity|Electricity|Biomass         GW     0.0000     0.0004
# 13        Capacity|Electricity|Biomass         GW     0.0000     0.0000
# 14        Capacity|Electricity|Biomass         GW    12.6700    19.4200
# 15        Capacity|Electricity|Biomass         GW     0.0000     0.0790
# 16        Capacity|Electricity|Biomass         GW     0.0000     0.0005
# 17        Capacity|Electricity|Biomass         GW     0.0000     0.0851
# 18        Capacity|Electricity|Biomass         GW     0.0000     0.0005
# 19        Capacity|Electricity|Biomass         GW     0.0304     0.7505
# 20        Capacity|Electricity|Biomass         GW     0.8629     1.2150
# 21        Capacity|Electricity|Biomass         GW     0.5020     0.7703
# 22        Capacity|Electricity|Biomass         GW     9.8620    13.0800
# 23        Capacity|Electricity|Biomass         GW    23.9200    35.4000
# 24           Capacity|Electricity|Coal         GW     0.8843     1.4470
# 25           Capacity|Electricity|Coal         GW   303.6000   511.4000
# 26           Capacity|Electricity|Coal         GW   159.2000   122.9000
# 27           Capacity|Electricity|Coal         GW    74.0700    95.0600
# 28           Capacity|Electricity|Coal         GW    41.6100    41.4900
# 29           Capacity|Electricity|Coal         GW     8.8360    13.1200
# ...                                ...        ...        ...        ...
# 55150           Emissions|CO2|Land Use  Mt CO2/yr     5.1088     1.8018
# 55173     -0.6394     -0.2421     -0.1617
# 55174     -0.9158     -1.8104      0.0000
# 55175      0.0000      0.0000      0.0000
# 55176     -0.8120     -0.5041     -6.0614
# 55177    -12.4764    -11.0678     -9.6079
# 55178     -0.7402     -1.0791     -0.3983
# 55179    -90.6408    -62.3360    -27.0114
#
# [55180 rows x 16 columns]

# %%
print(df_remind.loc[(df_remind.Region == 'USA') & (df_remind.Variable == 'Price|Carbon') 
                    & (df_remind.Scenario == 'SSP1-19-SPA1-V17')])
# Out:
#               Model          Scenario Region      Variable           Unit  \
# 4908  REMIND-MAGPIE  SSP1-19-SPA1-V17    USA  Price|Carbon  US$2005/t CO2
#
#       2005  2010  2020   2030   2040   2050   2060   2070   2080   2090   2100
# 4908   0.0   0.0  12.0  1.145  1.865  3.038  4.949  8.062  13.13  21.39  34.84

# %%
#IMAGE model

model_name_image = 'IMAGE'


data_file_image = data_path + 'IMAGE_SSP1-1.9_SSP2-1.9/IMAGE_SSP1-1.9_SSP2-1.9_and_baselines.xlsx'

scenario_names_image = ['SSP1-19-SPA0-V17', 'SSP1-Ref-SPA0-V17', 'SSP2-LF-SPA2-V17', 'SSP2-Ref-SPA0-V17']  

variable_names_image = ['Emissions|CO2', 'Emissions|Kyoto Gases','Emissions|CO2|Carbon Capture and Storage|Biomass',
                  'Emissions|CO2|Land Use|Carbon Sequestration', 'Emissions|CO2|Land Use|Negative',
                        'Investment|Energy Supply|Electricity|Non-fossil|Biomass|w/ CCS','Price|Carbon']

df_image = pd.read_excel(data_file_image, sheet_name=0)


# Create a regional dictionary
regions_names_image = {
    "World": ['EARTH', 'WLD'],
    "BRA": ['BRA'],
    "CAN": ['CAN'],
    "CEU": ['ALB', 'BIH', 'BGR', 'HRV', 'CYP', 'CZE', 'EST', 'HUN', 'LVA', 'LTU', 'MKD', 'POL', 'ROU', 'SRB', 'MNE',
            'SVK', 'SVN'],
    "CHN": ['CHN', 'TWN', 'HKG', 'MAC', 'MNG'],
    "EAF": ['BDI', 'COM', 'ETH', 'ERI', 'DJI', 'KEN', 'MDG', 'MUS', 'RWA', 'SYC', 'SOM', 'SDN', 'SSD', 'UGA'],
    "INDIA": ['IND'],
    "INDO": ['IDN', 'PNG', 'TLS'],
    "JAP": ['JPN'],
    "KOR": ['KOR', 'PRK'],
    "ME": ['BHR', 'IRN', 'IRQ', 'ISR', 'JOR', 'KWT', 'LBN', 'OMN', 'QAT', 'SAU', 'SYR', 'ARE', 'YEM'],
    "MEX": ['MEX'],
    "NAF": ['DZA', 'LBY', 'MAR', 'TUN', 'EGY'],
    "OCE": ['WSM', 'AUS', 'SLB', 'COK', 'FJI', 'KIR', 'NRU', 'VUT', 'NZL', 'NIU', 'FSM', 'MHL', 'PLW', 'PCN', 'TUV'],
    "RCAM": ['BHS', 'BRB', 'ATG', 'BLZ', 'VGB', 'CRI', 'DOM', 'SLV', 'GRD', 'GTM', 'HTI', 'HND', 'JAM', 'ABW', 'NIC',
             'PAN', 'AIA', 'KNA', 'LCA', 'VCT', 'TTO', 'TCA', 'TKL', 'TON', ''],
    "RSAF": ['AGO', 'BWA', 'LSO', 'MWI', 'MOZ', 'NAM', 'ZWE', 'SWZ', 'TZA', 'ZMB'],
    "RSAM": ['ARG', 'BOL', 'CHL', 'COL', 'ECU', 'GUY', 'PRY', 'PER', 'SUR', 'URY', 'VEN'],
    "RSAS": ['AFG', 'BGD', 'BTN', 'MDV', 'NPL', 'PAK', 'LKA'],
    "RUS": ['RUS', 'AZE', 'ARM', 'GEO'],
    "SAF": ['ZAF'],
    "SEAS": ['BRN', 'MMR', 'KHM', 'LAO', 'MYS', 'PHL', 'SGP', 'THA', 'VNM'],
    "STAN": ['KAZ', 'KGZ', 'TKM', 'TJK', 'UZB'],
    "TUR": ['TUR'],
    "UKR": ['UKR', 'BLR', 'MDA'],
    "USA": ['USA'],
    "WAF": ['CAM', 'CPV', 'CAF', 'TCD', 'COD', 'COG', 'BEN', 'GNQ', 'GAB', 'GNB', 'GHA', 'GIN', 'CIV', 'LBR', 'MLI',
            'MRT', 'NER', 'NGA', 'GNB', 'SHN', 'STP', 'SEN', 'SLE', 'TGO', 'BFA'],
    "WEU": ['AND', 'AUT', 'BEL', 'DNK', 'FIN', 'FRA', 'DEU', 'GRC', 'VAT', 'ISL', 'IRL', 'ITA', 'LIE', 'LUX', 'MCO',
            'NLD', 'NOR', 'PRT', 'SMR', 'ESP', 'SWE', 'CHE', 'GBR', 'MLT']
}
print(df_image)
# Out:
#        Model          Scenario Region                       Variable  \
# 0      IMAGE  SSP1-19-SPA0-V17    BRA            Agricultural Demand
# 1      IMAGE  SSP1-19-SPA0-V17    CAN            Agricultural Demand
# 2      IMAGE  SSP1-19-SPA0-V17    CEU            Agricultural Demand
# 3      IMAGE  SSP1-19-SPA0-V17    CHN            Agricultural Demand
# 4      IMAGE  SSP1-19-SPA0-V17    EAF            Agricultural Demand
# 5      IMAGE  SSP1-19-SPA0-V17  INDIA            Agricultural Demand
# 6      IMAGE  SSP1-19-SPA0-V17   INDO            Agricultural Demand
# 7      IMAGE  SSP1-19-SPA0-V17    JAP            Agricultural Demand
# 8      IMAGE  SSP1-19-SPA0-V17    KOR            Agricultural Demand
# 9      IMAGE  SSP1-19-SPA0-V17     ME            Agricultural Demand
# 10     IMAGE  SSP1-19-SPA0-V17    MEX            Agricultural Demand
# 11     IMAGE  SSP1-19-SPA0-V17    NAF            Agricultural Demand
# 12     IMAGE  SSP1-19-SPA0-V17    OCE            Agricultural Demand
# 13     IMAGE  SSP1-19-SPA0-V17   RCAM            Agricultural Demand
# 14     IMAGE  SSP1-19-SPA0-V17   RSAF            Agricultural Demand
# 15     IMAGE  SSP1-19-SPA0-V17   RSAM            Agricultural Demand
# 16     IMAGE  SSP1-19-SPA0-V17   RSAS            Agricultural Demand
# 17     IMAGE  SSP1-19-SPA0-V17    RUS            Agricultural Demand
# 18     IMAGE  SSP1-19-SPA0-V17    SAF            Agricultural Demand
# 19     IMAGE  SSP1-19-SPA0-V17   SEAS            Agricultural Demand
# 20     IMAGE  SSP1-19-SPA0-V17   STAN            Agricultural Demand
# 21     IMAGE  SSP1-19-SPA0-V17    TUR            Agricultural Demand
# 22     IMAGE  SSP1-19-SPA0-V17    UKR            Agricultural Demand
# 23     IMAGE  SSP1-19-SPA0-V17    USA            Agricultural Demand
# 24     IMAGE  SSP1-19-SPA0-V17    WAF            Agricultural Demand
# 25     IMAGE  SSP1-19-SPA0-V17    WEU            Agricultural Demand
# 26     IMAGE  SSP1-19-SPA0-V17  World            Agricultural Demand
# 27     IMAGE  SSP1-19-SPA0-V17    BRA  Agricultural Demand|Bioenergy
# 28     IMAGE  SSP1-19-SPA0-V17    CAN  Agricultural Demand|Bioenergy
# 29     IMAGE  SSP1-19-SPA0-V17    CEU  Agricultural Demand|Bioenergy
# ...      ...               ...    ...                            ...
# 70165  IMAGE  SSP2-LF-SPA2-V17    WAF                 Yield|Oilcrops
# 70166  IMAGE  SSP2-LF-SPA2-V17    WEU                 Yield|Oilcrops
# 70167  IMAGE  SSP2-LF-SPA2-V17  World                 Yield|Oilcrops
# 70168  IMAGE  SSP2-LF-SPA2-V17    BRA               Yield|Sugarcrops
# 70169  IMAGE  SSP2-LF-SPA2-V17    CAN               Yield|Sugarcrops
# 70170  IMAGE  SSP2-LF-SPA2-V17    CEU               Yield|Sugarcrops
# 70171  IMAGE  SSP2-LF-SPA2-V17    CHN               Yield|Sugarcrops
# 70172  IMAGE  SSP2-LF-SPA2-V17    EAF               Yield|Sugarcrops
# 70173  IMAGE  SSP2-LF-SPA2-V17  INDIA               Yield|Sugarcrops
# 70174  IMAGE  SSP2-LF-SPA2-V17   INDO               Yield|Sugarcrops
# 70175  IMAGE  SSP2-LF-SPA2-V17    JAP               Yield|Sugarcrops
# 70176  IMAGE  SSP2-LF-SPA2-V17    KOR               Yield|Sugarcrops
# 70177  IMAGE  SSP2-LF-SPA2-V17     ME               Yield|Sugarcrops
# 70178  IMAGE  SSP2-LF-SPA2-V17    MEX               Yield|Sugarcrops
# 70179  IMAGE  SSP2-LF-SPA2-V17    NAF               Yield|Sugarcrops
# 70180  IMAGE  SSP2-LF-SPA2-V17    OCE               Yield|Sugarcrops
# 70181  IMAGE  SSP2-LF-SPA2-V17   RCAM               Yield|Sugarcrops
# 70182  IMAGE  SSP2-LF-SPA2-V17   RSAF               Yield|Sugarcrops
# 70183  IMAGE  SSP2-LF-SPA2-V17   RSAM               Yield|Sugarcrops
# 70184  IMAGE  SSP2-LF-SPA2-V17   RSAS               Yield|Sugarcrops
# 70185  IMAGE  SSP2-LF-SPA2-V17    RUS               Yield|Sugarcrops
# 70186  IMAGE  SSP2-LF-SPA2-V17    SAF               Yield|Sugarcrops
# 70187  IMAGE  SSP2-LF-SPA2-V17   SEAS               Yield|Sugarcrops
# 70188  IMAGE  SSP2-LF-SPA2-V17   STAN               Yield|Sugarcrops
# 70189  IMAGE  SSP2-LF-SPA2-V17    TUR               Yield|Sugarcrops
# 70190  IMAGE  SSP2-LF-SPA2-V17    UKR               Yield|Sugarcrops
# 26     1.246616e+04  1.360284e+04
# 27     1.171493e+03  1.441050e+03
# 28     4.063665e-07  4.183174e-08
# 29     1.924431e+02  2.089790e+02
# ...             ...           ...
# 70165  4.788724e+00  4.891604e+00
# 70166  3.586966e+00  3.662492e+00
# 70167  4.402872e+00  4.477293e+00
# 70168  2.440168e+01  2.644570e+01
# 70169  0.000000e+00  0.000000e+00
# 70170  0.000000e+00  0.000000e+00
# 70171  0.000000e+00  0.000000e+00
# 70172  0.000000e+00  0.000000e+00
# 70173  0.000000e+00  0.000000e+00
# 70174  0.000000e+00  0.000000e+00
# 70175  0.000000e+00  0.000000e+00
# 70176  0.000000e+00  0.000000e+00
# 70177  0.000000e+00  0.000000e+00
# 70178  0.000000e+00  0.000000e+00
# 70179  0.000000e+00  0.000000e+00
# 70180  0.000000e+00  0.000000e+00
# 70181  0.000000e+00  0.000000e+00
# 70182  0.000000e+00  0.000000e+00
# 70183  0.000000e+00  0.000000e+00
# 70184  0.000000e+00  0.000000e+00
# 70185  0.000000e+00  0.000000e+00
# 70186  0.000000e+00  0.000000e+00
# 70187  0.000000e+00  0.000000e+00
# 70188  0.000000e+00  0.000000e+00
# 70189  0.000000e+00  0.000000e+00
# 70190  0.000000e+00  0.000000e+00
# 70191  0.000000e+00  0.000000e+00
# 70192  0.000000e+00  0.000000e+00
# 70193  0.000000e+00  0.000000e+00
# 70194  1.847045e+00  6.731887e+00
#
# [70195 rows x 16 columns]

# %%
#exclude scenarios that have mireported prices: Carbon prices below 5 USD/tCO2 in 2030 or reported as NaN

#scen_to_exclude = df_image.filter(Variable='Price|Carbon', year=range(2030, 2101, 10))
#misc = scen_to_exclude.validate({'Price|Carbon': {'lo': 5, 'year': 2030}}, exclude_on_fail=True)

#image_scen_w_invalid_CarbonPrice = df_image.loc[(df_image.Variable == 'Price|Carbon') & (df_image[2030] < 5)].Scenario.unique()
print(image_scen_w_invalid_CarbonPrice)

#print(df_image[~df_image.Scenario.isin(image_scen_w_invalid_CarbonPrice)])

def delete_invalid_carbon_price(main_df):
    scens_to_delete = main_df.loc[(main_df.Variable == 'Price|Carbon') & (main_df[2030] < 5)].Scenario.unique() + main_df.loc[]
    return main_df[~main_df.Scenario.isin(scens_to_delete)]

df_image = delete_invalid_carbon_price(df_image)
df_message = delete_invalid_cabon_price(df_message)
df_remind = delete_invalid_cabon_price(df_remind)
# Out:
# ['SSP1-Ref-SPA0-V17' 'SSP2-Ref-SPA0-V17']
# Empty DataFrame
# Columns: [Model, Scenario, Region, Variable, Unit, 2005, 2010, 2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100]
# Index: []

# %%
#check if any price|carbon values are missing
df_image.loc[(df_image.Variable == 'Price|Carbon')].isnull().values.any()
df_remind.loc[(df_remind.Variable == 'Price|Carbon')].isnull().values.any()
# Out:
# False

# %%
print(df_image.loc[(df_image.Region == 'USA') & (df_image.Variable == 'Price|Carbon') 
                    & (df_image.Scenario == 'SSP1-19-SPA0-V17')])
# Out:
#        Model          Scenario Region      Variable           Unit  2005  \
# 11150  IMAGE  SSP1-19-SPA0-V17    USA  Price|Carbon  US$2005/t CO2   0.0
# 25189  IMAGE  SSP1-19-SPA0-V17    USA  Price|Carbon  US$2005/t CO2   0.0
#
#        2010     2020        2030        2040        2050        2060  \
# 11150   0.0  90.4554  359.173629  429.445912  444.229348  436.761808
# 25189   0.0  90.4554  359.173629  429.445912  444.229348  436.761808
#
#              2070        2080        2090        2100
# 11150  379.722823  280.648083  196.661433  148.878879
# 25189  379.722823  280.648083  196.661433  148.878879

# %% [markdown]
# # CALCULATING HISTORICAL EMISSIONS FOR EQUITY SCHEMES

# %%
#Set up mdf_model dataframe (historic emission data for model regions)

def masterdf_calc(regions_names):
    mdf = pd.DataFrame(columns=['Year','Country','Value','Variable','Unit','Model','Scenario'])
    
    # PRIMAP Filter
    scen='HISTCR'
    cat='IPCM0EL'
    gas='KYOTOGHGAR4' #'CO2'
    
    for region in regions_names:                                      
        # Filter for countries in region, transpose (to get years on rows) and sum over countries
        cfiltdata=primap_in.loc[(primap_in.category==cat)&
                      (primap_in.scenario==scen)&
                      (primap_in.country.isin(regions_names[region]))&
                      (primap_in.entity==gas)].iloc[:,5:].transpose()

        tempdf=pd.DataFrame(columns=['Year','Country','Value','Variable','Unit','Model','Scenario'])
        tempdf['Year']=cfiltdata.index
        tempdf['Value']=cfiltdata.sum(axis=1).values*10**(-3) # Convert from Gg in Mt
        tempdf['Country']=region
        tempdf['Variable']='Kyoto Gases' #'CO2'
        tempdf['Unit']='Mt/yr'
        tempdf['Model']='PRIMAP'
        tempdf['Scenario']='HIST'

        mdf=mdf.append(tempdf,ignore_index=True)
    return mdf
        
mdf_remind = masterdf_calc(regions_names_remind)
mdf_image = masterdf_calc(regions_names_image)
mdf_message = masterdf_calc(regions_names_message)

# %%
#add historic landuse emissions (FAO_data)

def hist_landem_calc(regions_names):
    mdf = pd.DataFrame(columns=['Year','Country','Value_2','Variable','Unit','Model','Scenario'])
    # FAO Filter
    
    item='Land Use total'
    element='Net emissions/removals (CO2eq)'
    
    for region in regions_names:                                      
        # Filter for countries in region, transpose (to get years on rows) and sum over countries
        cfiltdata=FAO_data.loc[(FAO_data.Item==item)&
                      (FAO_data.Country_code.isin(regions_names[region]))&
                      (FAO_data.Element==element)].iloc[:,8:].transpose()
        
        tempdf=pd.DataFrame(columns=['Year','Country','Value_2','Variable','Unit','Model','Scenario'])
        tempdf['Year']=cfiltdata.index
        tempdf['Value_2']=cfiltdata.sum(axis=1).values*10**(-3) # Convert from Gg in Mt
        tempdf['Country']=region
        tempdf['Variable']='Kyoto Gases' #'CO2'
        tempdf['Unit']='Mt/yr'
        tempdf['Model']='PRIMAP'
        mdf=mdf.append(tempdf,ignore_index=True)
    return mdf
        
m_remind = hist_landem_calc(regions_names_remind)
m_image = hist_landem_calc(regions_names_image)
m_message = hist_landem_calc(regions_names_message)

# %%
def add_FAO_data_calc(mdf, m_df): 
    years_todel = list(range(1850, 1990))
    ranger = [str(x) for x in years_todel]

    for ye in mdf.Year:
        if ye in ranger:
            mdf = mdf[mdf.Year != ye]

    mdf = mdf.reset_index()
    
    df_merge = pd.merge(mdf, m_df, on = mdf.index, how = 'left')
    df_merge = df_merge.drop(columns=['Country_y', 'Variable_y', 'Unit_y', 'Model_y', 'Scenario_y', 'key_0', 'index', 'Year_y'])

    df_merge['Value_sum']= df_merge['Value']+df_merge['Value_2']

    df_merge.columns = ['Year', 'Country', 'Value', 'Variable', 'Unit', 'Model', 'Scenario', 'Value_2', 'Value_sum']
    df_merge = df_merge.drop(columns = ['Value_2', 'Value'])

    df_merge.rename(columns = {'Value_sum':'Value'}, inplace = True)

    return(df_merge)

mdf_remind = add_FAO_data_calc(mdf_remind, m_remind)
mdf_image = add_FAO_data_calc(mdf_image, m_image)
mdf_message = add_FAO_data_calc(mdf_message, m_message)
#print(mdf_image)

# %%
#%% DERIVE CUMULATIVE EMISSIONS FROM 1990 UP TO 2015

def cum_em_calc(mdf):


    #cum_em_df = pd.DataFrame(index=mdf.Country.unique(), columns=['Cum_Em_CO2_Gg'])
    #for region in cum_em_df.index:
     #   cum_em_df.loc[region, :] = mdf.loc[(mdf.Country == region) &
      #                                     (mdf.Year >= str(date_cumulative_beginning)) &
       #                                    (mdf.Year < str(end_historical_data)), 'Value'].sum(axis=0) 

    cum_em_df = pd.DataFrame(index=mdf.Country.unique(), columns=['Cum_Em_CO2_Gg'])
    for region in cum_em_df.index:
        cum_em_df.loc[region, :] = mdf.loc[(mdf.Country == region) &
                                           (mdf.Year >= str(date_cumulative_beginning)) &
                                           (mdf.Year < str(end_historical_data+1)), 'Value'].sum(axis=0)     
    return cum_em_df


cum_em_df_remind = cum_em_calc(mdf_remind)
cum_em_df_image = cum_em_calc(mdf_image)
cum_em_df_message = cum_em_calc(mdf_message)

# %% [markdown]
# # ADDING CUMULATIVE EMISSIONS TO THE DATASETS

# %%
#DERIVE RELEVANT QUANTITIES ON REGIONAL LEVEL - IMAGE
#Set up main dataframe with CUM_CO2 and CUM_CDR

var_image={'Emissions|CO2':'Total_CO2',
           'Emissions|Kyoto Gases': 'Total_GHG',
       'Emissions|CO2|Carbon Capture and Storage|Biomass':'BECCS',
       'Emissions|CO2|Land Use|Carbon Sequestration':'LANDCDR',
        'Investment|Energy Supply|Electricity|Non-fossil|Biomass|w/ CCS':'BECCS_Investments',
        'Price|Carbon':'Carbon_Price'}
variable_names = ['Emissions|CO2','Emissions|Kyoto Gases','Carbon Sequestration|Land Use','Carbon Sequestration|CCS|Biomass',
                  'Emissions|CO2|Carbon Capture and Storage|Biomass', 'Emissions|CO2|Land Use|Carbon Sequestration', 
                  'Emissions|CO2|Land Use|Negative','Investment|Energy Supply|Electricity|Non-fossil|Biomass|w/ CCS',
                    'Price|Carbon']




years=df_image.keys()[7:]                # start in 2020

def main_df(model, hist_data, master_dataframe, variables, model_name):
    
    red_dat_ref=model.loc[model.Variable.isin(variable_names)]
    
    full_df=pd.DataFrame(columns=['MODEL','Region','Scenario','Year','Total_CO2','Total_GHG','BECCS','LANDCDR',
                              'TOTAL_CDR','CO2_Emissions','CUM_CO2','CUM_CDR', 'Unit_CO2','BECCS_Investments', 
                            'CUM_BECCS_Investments', 'Unit_Investment','Carbon_Price','Unit_CarbonPrice'])
    full_df["Unit_CO2"]= 'Mt/yr'
    full_df["Unit_Investment"]= 'billion US$2005/yr' #for MESSAGE: billion US$2010/yr
    full_df["Unit_CarbonPrice"]= 'US$2005/t CO2'   #for MESSAGE: US$2010/t CO2
    full_df["MODEL"] = model_name


    for scen,reg in itertools.product(red_dat_ref.Scenario.unique(),red_dat_ref.Region.unique()): ## for IMAGE / REMIND
    #for scen,reg in itertools.product(['SSP1-19','LowEnergyDemand'], red_dat_ref.Region.unique()): ## for MESSAGE, because SSP2 scenarios don't have all values. Had to delete 'SSP1-26' because no GDP data
       # for scen in scenario_names_message:
    #for reg in red_dat_ref.Region.unique():
        tempdf = pd.DataFrame(columns=['MODEL','Region','Scenario','Year','Total_CO2','Total_GHG','BECCS','LANDCDR',
                                  'TOTAL_CDR','CO2_Emissions','CUM_CO2','CUM_CDR', 'Unit_CO2','BECCS_Investments', 
                            'CUM_BECCS_Investments', 'Unit_Investment','Carbon_Price','Unit_CarbonPrice'])
        tempdf["Unit_CO2"]= 'Mt/yr'
        tempdf["Unit_Investment"]= 'billion US$2005/yr'
        tempdf["Year"]=years
        tempdf["Region"]=reg
        tempdf["Scenario"]=scen
        tempdf["MODEL"] = model_name
        
        for var in red_dat_ref.Variable.unique():
            tempdf[variables[var]]=red_dat_ref.loc[(red_dat_ref.Scenario==scen)&
                            (red_dat_ref.Region==reg)&
                            (red_dat_ref.Variable==var),red_dat_ref.keys()[7:]].iloc[0,:].values

#        tempdf['LANDCDR'] = tempdf['LANDCDR']*(-1)                             # only Remind
#         num = tempdf['LANDCDR']._get_numeric_data() # because some LANDCDR values are negative (use this method when neg LANDCDR is related to BECCS)
        tempdf['TOTAL_CDR']=tempdf['BECCS']+tempdf['LANDCDR']
        num = tempdf['TOTAL_CDR']._get_numeric_data() # because some LANDCDR values are negative 
        num[num < 0] = 0
        #         tempdf['CO2_Emissions']=tempdf['Total_CO2']+tempdf['TOTAL_CDR']   #CO2_Emissions is CO2_em without CDR
        tempdf['CO2_Emissions']=tempdf['Total_GHG']+tempdf['TOTAL_CDR']       #Total_CO2 is CO2 with -CDR
                                                                            #Choose Total_CO2 or Total_GHG



    # ADD HISTORIC EMISSIONS UP TO 2015 AND FILL IN BETWEEN 2015 AND 2020 
        for reg in tempdf.Region.unique():    
        # Fill in years between 2015 and 2020 
            add15_to_20=5*0.5*(master_dataframe.loc[(master_dataframe.Country==reg)&(master_dataframe.Year==str(end_historical_data)),'Value'].values[0]
                               +tempdf.loc[(tempdf.Region==reg)&(tempdf.Year==beginning_modelled_data),'CO2_Emissions'])

        #Add cumulative historic emissions up to 2015
            add15_to_20+=hist_data.loc[reg,'Cum_Em_CO2_Gg']

# Add cumulative emissions to model 2020 levels
            tempdf.loc[(tempdf.Region==reg)&(tempdf.Year==beginning_modelled_data),'CUM_CO2']=add15_to_20    

    # DERIVE CUMULATIVE CDR FROM 2020
        tempdf['CUM_CDR']=tempdf.loc[tempdf['Year']==beginning_modelled_data,'TOTAL_CDR']
    
        for year in years[1:]:
        # 10 year steps but emissions in CO2/yr, interpolate linearly
            cumco2=tempdf.loc[tempdf['Year']==year-10,'CUM_CO2'].values+10*0.5*(tempdf.loc[tempdf['Year']==year,'CO2_Emissions'].values+tempdf.loc[tempdf['Year']==year-10,'CO2_Emissions'].values)
            cumcdr=tempdf.loc[tempdf['Year']==year-10,'CUM_CDR'].values+10*0.5*(tempdf.loc[tempdf['Year']==year,'TOTAL_CDR'].values+tempdf.loc[tempdf['Year']==year-10,'TOTAL_CDR'].values)
            
            tempdf.loc[tempdf['Year']==year,'CUM_CO2']=cumco2 
            tempdf.loc[tempdf['Year']==year,'CUM_CDR']=cumcdr 
            
        # cumulative investments from 2020
        tempdf['CUM_BECCS_Investments']=tempdf.loc[tempdf['Year']==beginning_modelled_data,'BECCS_Investments']
        
        for year in years[1:]: 
            cuminv=tempdf.loc[tempdf['Year']==year-10,'CUM_BECCS_Investments'].values+10*0.5*(tempdf.loc[tempdf['Year']==year,'BECCS_Investments'].values+tempdf.loc[tempdf['Year']==year-10,'BECCS_Investments'].values)
            tempdf.loc[tempdf['Year']==year,'CUM_BECCS_Investments']=cuminv
    
        full_df=full_df.append(tempdf,ignore_index=True)

# Correct for 'object' datatypes in output
        full_df['CUM_CO2']=full_df['CUM_CO2'].astype('float64', copy=True)
        full_df['Unit_CO2'] = 'Mt/yr'
        full_df['Unit_Investment'] = 'billion US$2005/yr'
        full_df["Unit_CarbonPrice"]= 'US$2005/t CO2' 
        
    return full_df
    
    
    
main_image = main_df(df_image, cum_em_df_image, mdf_image, var_image, model_name_image)
#main_message = main_df(df_message, cum_em_df_message, mdf_message, var_message, model_name_message)
#main_remind = main_df(df_remind, cum_em_df_remind, mdf_remind, var_remind, model_name_remind)

# %%
print(main_image)
# Out:
#      MODEL Region          Scenario  Year     Total_CO2     Total_GHG  \
# 0    IMAGE    BRA  SSP1-19-SPA0-V17  2020   1027.143687   1669.133057
# 1    IMAGE    BRA  SSP1-19-SPA0-V17  2030    454.394587   1031.937012
# 2    IMAGE    BRA  SSP1-19-SPA0-V17  2040    700.045868   1324.442993
# 3    IMAGE    BRA  SSP1-19-SPA0-V17  2050    142.483662    703.756897
# 4    IMAGE    BRA  SSP1-19-SPA0-V17  2060     20.306294    568.658020
# 5    IMAGE    BRA  SSP1-19-SPA0-V17  2070   -206.553789    349.490692
# 6    IMAGE    BRA  SSP1-19-SPA0-V17  2080   -527.841609     27.446051
# 7    IMAGE    BRA  SSP1-19-SPA0-V17  2090   -522.033610     35.775421
# 8    IMAGE    BRA  SSP1-19-SPA0-V17  2100   -748.534256   -189.222900
# 9    IMAGE    CAN  SSP1-19-SPA0-V17  2020    405.788175    529.120117
# 10   IMAGE    CAN  SSP1-19-SPA0-V17  2030    250.932744    323.373505
# 485  billion US$2005/yr   1090.909092    US$2005/t CO2
#
# [486 rows x 18 columns]

# %%
# DERIVE RELEVANT QUANTITIES ON REGIONAL LEVEL - REMIND
#Set up main dataframe with CUM_CO2 and CUM_CDR

var_remind={'Emissions|CO2':'Total_CO2',
            'Emissions|Kyoto Gases': 'Total_GHG',
            'Emissions|CO2|Carbon Capture and Storage|Biomass':'BECCS',
            'Emissions|CO2|Land Use|Negative':'LANDCDR',
           'Investment|Energy Supply|Electricity|Non-fossil|Biomass|w/ CCS':'BECCS_Investments',
            'Price|Carbon':'Carbon_Price'}
variable_names = ['Emissions|CO2','Emissions|Kyoto Gases','Carbon Sequestration|Land Use','Carbon Sequestration|CCS|Biomass',
                  'Emissions|CO2|Carbon Capture and Storage|Biomass', 'Emissions|CO2|Land Use|Carbon Sequestration', 
                  'Emissions|CO2|Land Use|Negative','Investment|Energy Supply|Electricity|Non-fossil|Biomass|w/ CCS',
                    'Price|Carbon']




years=df_image.keys()[7:]                # start in 2020

def main_df(model, hist_data, master_dataframe, variables, model_name):
    
    red_dat_ref=model.loc[model.Variable.isin(variable_names)]
    
    full_df=pd.DataFrame(columns=['MODEL','Region','Scenario','Year','Total_CO2','Total_GHG','BECCS','LANDCDR',
                              'TOTAL_CDR','CO2_Emissions','CUM_CO2','CUM_CDR', 'Unit_CO2','BECCS_Investments', 
                            'CUM_BECCS_Investments', 'Unit_Investment','Carbon_Price','Unit_CarbonPrice'])
    full_df["Unit_CO2"]= 'Mt/yr'
    full_df["Unit_Investment"]= 'billion US$2005/yr' #for MESSAGE: billion US$2010/yr
    full_df["Unit_CarbonPrice"]= 'US$2005/t CO2'   #for MESSAGE: US$2010/t CO2
    full_df["MODEL"] = model_name


    for scen,reg in itertools.product(red_dat_ref.Scenario.unique(),red_dat_ref.Region.unique()): ## for IMAGE / REMIND
    #for scen,reg in itertools.product(['SSP1-19','LowEnergyDemand'], red_dat_ref.Region.unique()): ## for MESSAGE, because SSP2 scenarios don't have all values. Had to delete 'SSP1-26' because no GDP data
       # for scen in scenario_names_message:
    #for reg in red_dat_ref.Region.unique():
        tempdf = pd.DataFrame(columns=['MODEL','Region','Scenario','Year','Total_CO2','Total_GHG','BECCS','LANDCDR',
                                  'TOTAL_CDR','CO2_Emissions','CUM_CO2','CUM_CDR', 'Unit_CO2','BECCS_Investments', 
                            'CUM_BECCS_Investments', 'Unit_Investment','Carbon_Price','Unit_CarbonPrice'])
        tempdf["Unit_CO2"]= 'Mt/yr'
        tempdf["Unit_Investment"]= 'billion US$2005/yr'
        tempdf["Year"]=years
        tempdf["Region"]=reg
        tempdf["Scenario"]=scen
        tempdf["MODEL"] = model_name
        
        for var in red_dat_ref.Variable.unique():
            tempdf[variables[var]]=red_dat_ref.loc[(red_dat_ref.Scenario==scen)& (red_dat_ref.Region==reg) & 
                                                   (red_dat_ref.Variable==var),red_dat_ref.keys()[7:]].iloc[0,:].values

        tempdf['LANDCDR'] = tempdf['LANDCDR']*(-1)                             # only Remind
#         num = tempdf['LANDCDR']._get_numeric_data() # because some LANDCDR values are negative (use this method when neg LANDCDR is related to BECCS)
        tempdf['TOTAL_CDR']=tempdf['BECCS']+tempdf['LANDCDR']
        num = tempdf['TOTAL_CDR']._get_numeric_data() # because some LANDCDR values are negative 
        num[num < 0] = 0
        #         tempdf['CO2_Emissions']=tempdf['Total_CO2']+tempdf['TOTAL_CDR']   #CO2_Emissions is CO2_em without CDR
        tempdf['CO2_Emissions']=tempdf['Total_GHG']+tempdf['TOTAL_CDR']       #Total_CO2 is CO2 with -CDR
                                                                            #Choose Total_CO2 or Total_GHG



    # ADD HISTORIC EMISSIONS UP TO 2015 AND FILL IN BETWEEN 2015 AND 2020 
        for reg in tempdf.Region.unique():    
        # Fill in years between 2015 and 2020 
            add15_to_20=5*0.5*(master_dataframe.loc[(master_dataframe.Country==reg)&(master_dataframe.Year==str(end_historical_data)),'Value'].values[0]
                               +tempdf.loc[(tempdf.Region==reg)&(tempdf.Year==beginning_modelled_data),'CO2_Emissions'])

        #Add cumulative historic emissions up to 2015
            add15_to_20+=hist_data.loc[reg,'Cum_Em_CO2_Gg']

# Add cumulative emissions to model 2020 levels
            tempdf.loc[(tempdf.Region==reg)&(tempdf.Year==beginning_modelled_data),'CUM_CO2']=add15_to_20    

    # DERIVE CUMULATIVE CDR FROM 2020
        tempdf['CUM_CDR']=tempdf.loc[tempdf['Year']==beginning_modelled_data,'TOTAL_CDR']
    
        for year in years[1:]:
        # 10 year steps but emissions in CO2/yr, interpolate linearly
            cumco2=tempdf.loc[tempdf['Year']==year-10,'CUM_CO2'].values+10*0.5*(tempdf.loc[tempdf['Year']==year,'CO2_Emissions'].values+tempdf.loc[tempdf['Year']==year-10,'CO2_Emissions'].values)
            cumcdr=tempdf.loc[tempdf['Year']==year-10,'CUM_CDR'].values+10*0.5*(tempdf.loc[tempdf['Year']==year,'TOTAL_CDR'].values+tempdf.loc[tempdf['Year']==year-10,'TOTAL_CDR'].values)
            
            tempdf.loc[tempdf['Year']==year,'CUM_CO2']=cumco2 
            tempdf.loc[tempdf['Year']==year,'CUM_CDR']=cumcdr 
            
        # cumulative investments from 2020
        tempdf['CUM_BECCS_Investments']=tempdf.loc[tempdf['Year']==beginning_modelled_data,'BECCS_Investments']
        
        for year in years[1:]: 
            cuminv=tempdf.loc[tempdf['Year']==year-10,'CUM_BECCS_Investments'].values+10*0.5*(tempdf.loc[tempdf['Year']==year,'BECCS_Investments'].values+tempdf.loc[tempdf['Year']==year-10,'BECCS_Investments'].values)
            tempdf.loc[tempdf['Year']==year,'CUM_BECCS_Investments']=cuminv
    
        full_df=full_df.append(tempdf,ignore_index=True)

# Correct for 'object' datatypes in output
        full_df['CUM_CO2']=full_df['CUM_CO2'].astype('float64', copy=True)
        full_df['Unit_CO2'] = 'Mt/yr'
        full_df['Unit_Investment'] = 'billion US$2005/yr'
        full_df["Unit_CarbonPrice"]= 'US$2005/t CO2' 
        
    return full_df
    
    
    
#main_image = main_df(df_image, cum_em_df_image, mdf_image, var_image, model_name_image)
#main_message = main_df(df_message, cum_em_df_message, mdf_message, var_message, model_name_message)
main_remind = main_df(df_remind, cum_em_df_remind, mdf_remind, var_remind, model_name_remind)

# %%
print(main_remind)
# Out:
#       MODEL Region          Scenario  Year   Total_CO2  Total_GHG       BECCS  \
# 0    REMIND    AFR  SSP1-19-SPA1-V17  2020   1215.4939     3233.0      0.0060
# 1    REMIND    AFR  SSP1-19-SPA1-V17  2030   1212.0330     2952.0     30.8600
# 2    REMIND    AFR  SSP1-19-SPA1-V17  2040   1618.5552     3692.0    352.2000
# 3    REMIND    AFR  SSP1-19-SPA1-V17  2050    388.3696     2444.0    949.0000
# 4    REMIND    AFR  SSP1-19-SPA1-V17  2060   -814.2021      738.9   1144.0000
# 5    REMIND    AFR  SSP1-19-SPA1-V17  2070   -892.3965      368.6   1145.0000
# 6    REMIND    AFR  SSP1-19-SPA1-V17  2080  -1029.0042      138.4   1146.0000
# 7    REMIND    AFR  SSP1-19-SPA1-V17  2090  -1357.0127     -299.5   1146.0000
# 8    REMIND    AFR  SSP1-19-SPA1-V17  2100  -1670.9641     -797.5   1146.0000
# 9    REMIND    CHN  SSP1-19-SPA1-V17  2020   9004.3214    11750.0      0.0049
# 10   REMIND    CHN  SSP1-19-SPA1-V17  2030   5958.0022     7822.0     91.2200
# 11   REMIND    CHN  SSP1-19-SPA1-V17  2040   2758.0046     3952.0    754.1000
# 12   REMIND    CHN  SSP1-19-SPA1-V17  2050    200.2172     1142.0   1691.0000
# 13   REMIND    CHN  SSP1-19-SPA1-V17  2060  -1087.9968     -324.4   1832.0000
# 14   REMIND    CHN  SSP1-19-SPA1-V17  2070  -1526.0007     -872.6   1833.0000
# 15   REMIND    CHN  SSP1-19-SPA1-V17  2080  -1996.9798    -1509.0   1833.0000
# 16   REMIND    CHN  SSP1-19-SPA1-V17  2090  -2353.9654    -1933.0   1833.0000
# 17   REMIND    CHN  SSP1-19-SPA1-V17  2100  -2262.0013    -1906.0   1833.0000
# 18   REMIND    EUR  SSP1-19-SPA1-V17  2020   3360.1153     4228.0      0.0048
# 19   REMIND    EUR  SSP1-19-SPA1-V17  2030   2551.9972     3154.0     36.8300
# 20   REMIND    EUR  SSP1-19-SPA1-V17  2040   1918.9841     2453.0    305.6000
# 21   REMIND    EUR  SSP1-19-SPA1-V17  2050    474.1978      967.0    754.3000
# 22   REMIND    EUR  SSP1-19-SPA1-V17  2060   -379.5968      107.1    889.1000
# 23   REMIND    EUR  SSP1-19-SPA1-V17  2070   -646.0028     -149.7    889.1000
# 24   REMIND    EUR  SSP1-19-SPA1-V17  2080   -736.3000     -237.4    889.1000
# 25   REMIND    EUR  SSP1-19-SPA1-V17  2090   -769.8952     -275.6    889.1000
# 26   REMIND    EUR  SSP1-19-SPA1-V17  2100   -835.1995     -341.4    889.1000
# 27   REMIND    IND  SSP1-19-SPA1-V17  2020   3108.2835     4660.0      0.0046
# 28   REMIND    IND  SSP1-19-SPA1-V17  2030   2622.9776     3886.0     36.1600
# ..            ...              ...
# 618      3544.000    US$2005/t CO2
# 619      5760.000    US$2005/t CO2
# 620      9336.000    US$2005/t CO2
# 621         0.000    US$2005/t CO2
# 622       110.100    US$2005/t CO2
# 623       425.900    US$2005/t CO2
# 624       767.200    US$2005/t CO2
# 625      1466.000    US$2005/t CO2
# 626      2095.000    US$2005/t CO2
# 627      3544.000    US$2005/t CO2
# 628      5828.000    US$2005/t CO2
# 629      9302.000    US$2005/t CO2
# 630        12.000    US$2005/t CO2
# 631       119.900    US$2005/t CO2
# 632       425.900    US$2005/t CO2
# 633       767.200    US$2005/t CO2
# 634      1466.000    US$2005/t CO2
# 635      2095.000    US$2005/t CO2
# 636      3544.000    US$2005/t CO2
# 637      5750.000    US$2005/t CO2
# 638      9211.000    US$2005/t CO2
# 639         7.333    US$2005/t CO2
# 640       115.000    US$2005/t CO2
# 641       425.900    US$2005/t CO2
# 642       767.900    US$2005/t CO2
# 643      1466.000    US$2005/t CO2
# 644      2095.000    US$2005/t CO2
# 645      3545.000    US$2005/t CO2
# 646      5761.000    US$2005/t CO2
# 647      9233.000    US$2005/t CO2
#
# [648 rows x 18 columns]

# %%
#DERIVE RELEVANT QUANTITIES ON REGIONAL LEVEL - MESSAGE
#Set up main dataframe with CUM_CO2 and CUM_CDR for MESSAGE


var_message={'Emissions|CO2': 'Total_CO2',
            'Carbon Sequestration|CCS|Biomass': 'BECCS',
            'Carbon Sequestration|Land Use': 'LANDCDR',
            'Emissions|Kyoto Gases': 'Total_GHG',
            'Investment|Energy Supply|Electricity|Biomass|w/ CCS':'BECCS_Investments',
            'Price|Carbon':'Carbon_Price'}
variable_names_message = ['Emissions|CO2','Emissions|Kyoto Gases','Carbon Sequestration|Land Use','Carbon Sequestration|CCS|Biomass',
                  'Emissions|CO2|Carbon Capture and Storage|Biomass', 'Emissions|CO2|Land Use|Carbon Sequestration', 
                  'Emissions|CO2|Land Use|Negative','Investment|Energy Supply|Electricity|Biomass|w/ CCS',
                    'Price|Carbon']

years=df_image.keys()[7:]                # start in 2020

def main_df(model, hist_data, master_dataframe, variables, model_name):
    
    red_dat_ref=model.loc[model.Variable.isin(variable_names_message)]
    
    full_df=pd.DataFrame(columns=['MODEL','Region','Scenario','Year','Total_CO2','Total_GHG','BECCS','LANDCDR',
                                  'TOTAL_CDR','CO2_Emissions','CUM_CO2','CUM_CDR', 'Unit_CO2','BECCS_Investments',
                                  'CUM_BECCS_Investments', 'Unit_Investment','Carbon_Price','Unit_CarbonPrice'])
    full_df["Unit_CO2"]= 'Mt/yr'
    full_df["Unit_Investment"]= 'billion US$2010/yr' 
    full_df["Unit_CarbonPrice"]= 'US$2010/t CO2'   
    full_df["MODEL"] = model_name

    for scen,reg in itertools.product(['SSP1-19','LowEnergyDemand'], red_dat_ref.Region.unique()): ## for MESSAGE, because SSP2 scenarios don't have all values. Had to delete 'SSP1-26' because no GDP data
       #for scen in scenario_names_message:
    #for reg in red_dat_ref.Region.unique():
        tempdf = pd.DataFrame(columns=['MODEL','Region','Scenario','Year','Total_CO2','Total_GHG','BECCS','LANDCDR',
                                       'TOTAL_CDR','CO2_Emissions','CUM_CO2','CUM_CDR', 'Unit_CO2','BECCS_Investments',
                                       'CUM_BECCS_Investments', 'Unit_Investment','Carbon_Price','Unit_CarbonPrice'])
        tempdf["Unit_CO2"]= 'Mt/yr'
        tempdf["Unit_Investment"]= 'billion US$2010/yr'
        tempdf["Year"]=years
        tempdf["Region"]=reg
        tempdf["Scenario"]=scen
        tempdf["MODEL"] = model_name
        
        for var in red_dat_ref.Variable.unique():
#             print(var, reg, scen)

            try:
                tempdf[variables[var]]=red_dat_ref.loc[
                    (red_dat_ref.Scenario==scen) & (red_dat_ref.Region==reg) & (red_dat_ref.Variable==var),
                    red_dat_ref.keys()[7:]
                ].iloc[0,:].values
            except IndexError:
                tempdf[variables[var]] = "Nan"
                
#         num = tempdf['LANDCDR']._get_numeric_data() # because some LANDCDR values are negative (use this method when neg LANDCDR is related to BECCS)
        tempdf['TOTAL_CDR']=tempdf['BECCS']+tempdf['LANDCDR']
        num = tempdf['TOTAL_CDR']._get_numeric_data() # because some LANDCDR values are negative 
        num[num < 0] = 0
        #         tempdf['CO2_Emissions']=tempdf['Total_CO2']+tempdf['TOTAL_CDR']   #CO2_Emissions is CO2_em without CDR
        tempdf['CO2_Emissions']=tempdf['Total_GHG']+tempdf['TOTAL_CDR']       #Total_CO2 is CO2 with -CDR
                                                                            #Choose Total_CO2 or Total_GHG



    # ADD HISTORIC EMISSIONS UP TO 2015 AND FILL IN BETWEEN 2015 AND 2020 
        for reg in tempdf.Region.unique():    
        # Fill in years between 2015 and 2020 
            add15_to_20=5*0.5*(master_dataframe.loc[(master_dataframe.Country==reg)&(master_dataframe.Year==str(end_historical_data)),'Value'].values[0]
                               +tempdf.loc[(tempdf.Region==reg)&(tempdf.Year==beginning_modelled_data),'CO2_Emissions'])

        #Add cumulative historic emissions up to 2015
            add15_to_20+=hist_data.loc[reg,'Cum_Em_CO2_Gg']

# Add cumulative emissions to model 2020 levels
            tempdf.loc[(tempdf.Region==reg)&(tempdf.Year==beginning_modelled_data),'CUM_CO2']=add15_to_20    

    # DERIVE CUMULATIVE CDR FROM 2020
        tempdf['CUM_CDR']=tempdf.loc[tempdf['Year']==beginning_modelled_data,'TOTAL_CDR']
    
        for year in years[1:]:
        # 10 year steps but emissions in CO2/yr, interpolate linearly
            cumco2=tempdf.loc[tempdf['Year']==year-10,'CUM_CO2'].values+10*0.5*(tempdf.loc[tempdf['Year']==year,'CO2_Emissions'].values+tempdf.loc[tempdf['Year']==year-10,'CO2_Emissions'].values)
            cumcdr=tempdf.loc[tempdf['Year']==year-10,'CUM_CDR'].values+10*0.5*(tempdf.loc[tempdf['Year']==year,'TOTAL_CDR'].values+tempdf.loc[tempdf['Year']==year-10,'TOTAL_CDR'].values)
            
            tempdf.loc[tempdf['Year']==year,'CUM_CO2']=cumco2 
            tempdf.loc[tempdf['Year']==year,'CUM_CDR']=cumcdr 
            
        # cumulative investments from 2020
        tempdf['CUM_BECCS_Investments']=tempdf.loc[tempdf['Year']==beginning_modelled_data,'BECCS_Investments']
        
        for year in years[1:]: 
            cuminv=tempdf.loc[tempdf['Year']==year-10,'CUM_BECCS_Investments'].values+10*0.5*(tempdf.loc[tempdf['Year']==year,'BECCS_Investments'].values+tempdf.loc[tempdf['Year']==year-10,'BECCS_Investments'].values)
            tempdf.loc[tempdf['Year']==year,'CUM_BECCS_Investments']=cuminv
    
        full_df=full_df.append(tempdf,ignore_index=True)

# Correct for 'object' datatypes in output
        full_df['CUM_CO2']=full_df['CUM_CO2'].astype('float64', copy=True)
        full_df['Unit_CO2'] = 'Mt/yr'
        full_df['Unit_Investment'] = 'billion US$2010/yr'
        full_df["Unit_CarbonPrice"]= 'US$2010/t CO2' 
        
    return full_df

#print(df_message.Region.unique()) 
# print(df_message[(df_message.Variable == "Price|Carbon") & (df_message.Region =="CHN")])
# print(df_message.loc[df_message.Variable.isin(variable_names)].loc[
#     (df_message.Scenario=='LowEnergyDemand') & (df_message.Region=="CHN") & (df_message.Variable == "Price|Carbon")])
main_message = main_df(df_message, cum_em_df_message, mdf_message, var_message, model_name_message)

# %%
print(df_message.loc[df_message.Variable == 'Investment|Energy Supply|Electricity|Biomass|w/ CCS'])
# Out:
#                        Model                Scenario   Region  \
# 18902  MESSAGEix-GLOBIOM 1.0          CD-LINKS_INDCi  R11_AFR
# 20006  MESSAGEix-GLOBIOM 1.0          CD-LINKS_INDCi  R11_FSU
# 20374  MESSAGEix-GLOBIOM 1.0          CD-LINKS_INDCi  R11_LAM
# 20742  MESSAGEix-GLOBIOM 1.0          CD-LINKS_INDCi  R11_MEA
# 21464  MESSAGEix-GLOBIOM 1.0          CD-LINKS_INDCi  R11_PAO
# 21832  MESSAGEix-GLOBIOM 1.0          CD-LINKS_INDCi  R11_PAS
# 23262  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NDC2030i_1000      CHN
# 23630  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NDC2030i_1000       EU
# 24083  MESSAGEix-GLOBIOM 1.0            CD-LINKS_NPi      CHN
# 24451  MESSAGEix-GLOBIOM 1.0            CD-LINKS_NPi       EU
# 24819  MESSAGEix-GLOBIOM 1.0            CD-LINKS_NPi      IND
# 25117  MESSAGEix-GLOBIOM 1.0            CD-LINKS_NPi  R11_PAO
# 25485  MESSAGEix-GLOBIOM 1.0            CD-LINKS_NPi  R11_PAS
# 26775  MESSAGEix-GLOBIOM 1.0   CD-LINKS_NPi2020_1000      CHN
# 27143  MESSAGEix-GLOBIOM 1.0   CD-LINKS_NPi2020_1000       EU
# 27511  MESSAGEix-GLOBIOM 1.0   CD-LINKS_NPi2020_1000      IND
# 27879  MESSAGEix-GLOBIOM 1.0   CD-LINKS_NPi2020_1000  R11_AFR
# 45104  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand      CHN
# 45473  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand       EU
# 45843  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand      IND
# 46213  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand  R11_AFR
# 47322  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand  R11_FSU
# 47692  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand  R11_LAM
# 48062  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand  R11_MEA
# 48802  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand  R11_PAO
# 49172  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand  R11_PAS
# 52132  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand      USA
# 52548  MESSAGEix-GLOBIOM 1.0         LowEnergyDemand    World
# 52873    MESSAGE-GLOBIOM 1.0                 SSP1-19      CHN
# 53151    MESSAGE-GLOBIOM 1.0                 SSP1-19       EU
# 53429    MESSAGE-GLOBIOM 1.0                 SSP1-19      IND
# 53707    MESSAGE-GLOBIOM 1.0                 SSP1-19  R11_AFR
# 54541    MESSAGE-GLOBIOM 1.0                 SSP1-19  R11_FSU
# 54819    MESSAGE-GLOBIOM 1.0                 SSP1-19  R11_LAM
# 55097    MESSAGE-GLOBIOM 1.0                 SSP1-19  R11_MEA
# 55653    MESSAGE-GLOBIOM 1.0                 SSP1-19  R11_PAO
# 55931    MESSAGE-GLOBIOM 1.0                 SSP1-19  R11_PAS
# 58155    MESSAGE-GLOBIOM 1.0                 SSP1-19      USA
# 58492    MESSAGE-GLOBIOM 1.0                 SSP1-19    World
# 78945    MESSAGE-GLOBIOM 1.0                 SSP2-19  R11_MEA
# 80162    MESSAGE-GLOBIOM 1.0                 SSP2-19      USA
# 80184    MESSAGE-GLOBIOM 1.0                 SSP2-19    World
# 80357    MESSAGE-GLOBIOM 1.0                 SSP2-26      CHN
# 80434    MESSAGE-GLOBIOM 1.0                 SSP2-26      IND
#
#                                                 Variable                Unit  \
# 18902  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 20006  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 20374  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 20742  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 21464  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 21832  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 23262  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 23630  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 24083  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 24451  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 24819  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 25117  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 25485  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 26775  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 27143  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 27511  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 27879  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 45104  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 45473  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 45843  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 46213  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 47322  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 47692  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 48062  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 48802  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 49172  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 52132  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 52548  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 52873  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 53151  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 53429  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 53707  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 54541  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 54819  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 55097  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 55653  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 55931  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 58155  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 58492  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 78945  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 80162  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 80184  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 80357  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
# 80434  Investment|Energy Supply|Electricity|Biomass|w...  billion US$2010/yr
#
#        2005  2010  2020  2030      2040      2050      2060      2070  2080  \
# 18902   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 20006   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 20374   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 20742   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 21464   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 21832   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 23262   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 23630   0.0   0.0   0.0   0.0  0.000000  0.000000  0.142932  0.000000   0.0
# 24083   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 24451   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 24819   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 25117   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 25485   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 26775   0.0   0.0   0.0   0.0  0.000000  0.642508  0.000000  0.000000   0.0
# 27143   0.0   0.0   0.0   0.0  0.140484  0.000000  0.000000  0.071748   0.0
# 27511   0.0   0.0   0.0   0.0  0.000000  0.514440  0.000000  0.000000   0.0
# 27879   0.0   0.0   0.0   0.0  0.000000  0.000000  0.475813  0.000000   0.0
# 45104   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 45473   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 45843   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 46213   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 47322   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 47692   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 48062   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 48802   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 49172   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 52132   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 52548   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 52873   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 53151   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 53429   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 53707   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 54541   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 54819   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 55097   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 55653   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 55931   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 58155   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 58492   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 78945   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 80162   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 80184   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 80357   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
# 80434   0.0   0.0   0.0   0.0  0.000000  0.000000  0.000000  0.000000   0.0
#
#        2090      2100
# 18902   0.0  0.000000
# 20006   0.0  0.000000
# 20374   0.0  0.000000
# 20742   0.0  0.000000
# 21464   0.0  0.000000
# 21832   0.0  0.000000
# 23262   0.0  0.016827
# 23630   0.0  0.000000
# 24083   0.0  0.000000
# 24451   0.0  0.000000
# 24819   0.0  0.000000
# 25117   0.0  0.000000
# 25485   0.0  0.000000
# 26775   0.0  0.000000
# 27143   0.0  0.000000
# 27511   0.0  0.000000
# 27879   0.0  0.000000
# 45104   0.0  0.000000
# 45473   0.0  0.000000
# 45843   0.0  0.000000
# 46213   0.0  0.000000
# 47322   0.0  0.000000
# 47692   0.0  0.000000
# 48062   0.0  0.000000
# 48802   0.0  0.000000
# 49172   0.0  0.000000
# 52132   0.0  0.000000
# 52548   0.0  0.000000
# 52873   0.0  0.000000
# 53151   0.0  0.000000
# 53429   0.0  0.000000
# 53707   0.0  0.000000
# 54541   0.0  0.000000
# 54819   0.0  0.000000
# 55097   0.0  0.000000
# 55653   0.0  0.000000
# 55931   0.0  0.000000
# 58155   0.0  0.000000
# 58492   0.0  0.000000
# 78945   0.0  0.000000
# 80162   0.0  0.000000
# 80184   0.0  0.000000
# 80357   0.0  0.000000
# 80434   0.0  0.000000

# %%
#add a column Carbon_Price X TOTAL_CDR
# main_message[['Carbon_Price','TOTAL_CDR']] = main_message[['Carbon_Price','TOTAL_CDR']].astype(float)
# main_message['PriceXTotalCDR'] = main_message.Carbon_Price * main_message.TOTAL_CDR
# print(main_message)
#main_message['Carbon_Price'].values * main_message['TOTAL_CDR'].values
#price unit = $2005/ton
#CO2 unit = Mt/yr 

def withPriceXTotalCDR(main_df):
    main_df[['Carbon_Price','TOTAL_CDR']] = main_df[['Carbon_Price','TOTAL_CDR']].astype(float)
    main_df['PriceXTotalCDR'] = main_df['Carbon_Price'] * main_df['TOTAL_CDR'] * 1000000
    main_df['Unit_PriceXTotalCDR'] = 'US$2005/yr' #2010 for message
    return main_df

#main_message = withPriceXTotalCDR(main_message)
main_remind = withPriceXTotalCDR(main_remind)
main_image = withPriceXTotalCDR(main_image)

# %%
print(main_image)
# Out:
#      MODEL Region          Scenario  Year     Total_CO2     Total_GHG  \
# 0    IMAGE    BRA  SSP1-19-SPA0-V17  2020   1027.143687   1669.133057
# 1    IMAGE    BRA  SSP1-19-SPA0-V17  2030    454.394587   1031.937012
# 2    IMAGE    BRA  SSP1-19-SPA0-V17  2040    700.045868   1324.442993
# 3    IMAGE    BRA  SSP1-19-SPA0-V17  2050    142.483662    703.756897
# 4    IMAGE    BRA  SSP1-19-SPA0-V17  2060     20.306294    568.658020
# 5    IMAGE    BRA  SSP1-19-SPA0-V17  2070   -206.553789    349.490692
# 6    IMAGE    BRA  SSP1-19-SPA0-V17  2080   -527.841609     27.446051
# 481  9459.967773  283250.593750              Mio        551657
# 482  9531.094727  338902.500000              Mio        646613
# 483  9480.227539  399688.593750              Mio        741669
# 484  9325.707031  466015.812500              Mio        835699
# 485  9103.234375  538245.875000              Mio        927844
#
#      2016_emissions em_change
# 0       1376.243424  1.212818
# 1       1376.243424  0.749822
# 2       1376.243424  0.962361
# 3       1376.243424  0.574426
# 4       1376.243424  0.540126
# 5       1376.243424  0.569299
# 6       1376.243424  0.527828
# 7       1376.243424  0.532360
# 8       1376.243424  0.520884
# 9        789.660070  0.747532
# 10       789.660070  0.478060
# 11       789.660070  0.363751
# 12       789.660070  0.317902
# 13       789.660070  0.300565
# 14       789.660070  0.314033
# 15       789.660070  0.329651
# 16       789.660070  0.333863
# 17       789.660070  0.320161
# 18       800.735546  1.110187
# 19       800.735546  0.795036
# 20       800.735546  0.537784
# 21       800.735546  0.332207
# 22       800.735546  0.273147
# 23       800.735546  0.256727
# 24       800.735546  0.241575
# 25       800.735546  0.232883
# 26       800.735546  0.233938
# 27     12792.628402  0.819279
# 28     12792.628402  0.591444
# 29     12792.628402  0.261338
# ..              ...       ...
# 456     6493.149080  0.230165
# 457     6493.149080  0.245415
# 458     6493.149080  0.245646
# 459     1124.364242  1.671020
# 460     1124.364242  1.115094
# 461     1124.364242  0.714386
# 462     1124.364242  0.713439
# 463     1124.364242  0.635650
# 464     1124.364242  0.620149
# 465     1124.364242  0.697543
# 466     1124.364242  0.707169
# 467     1124.364242  0.779120
# 468     3316.334742  1.107664
# 469     3316.334742  0.772168
# 470     3316.334742  0.582453
# 471     3316.334742  0.469415
# 472     3316.334742  0.380569
# 473     3316.334742  0.336764
# 474     3316.334742  0.334854
# 475     3316.334742  0.334739
# 476     3316.334742  0.341776
# 477    47200.000000  1.150608
# 478    47200.000000  0.816135
# 479    47200.000000  0.537230
# 480    47200.000000  0.452156
# 481    47200.000000  0.339410
# 482    47200.000000  0.312877
# 483    47200.000000  0.302972
# 484    47200.000000  0.300040
# 485    47200.000000  0.298764
#
# [486 rows x 26 columns]

# %%
scen='SSP1-19-SPA1-V17'
single_scen=main_remind[main_remind.Region=='USA'].copy()
sns.lineplot(x='Year',y='TOTAL_CDR',data=single_scen,hue=main_remind.Scenario)
plt.legend(loc='lower left', bbox_to_anchor=(1,0),ncol=2)
#plt.yscale('log')

# %%
scen='SSP1-19-SPA1-V17'
single_scen=main_remind[main_remind.Region=='USA'].copy()
sns.lineplot(x='Year',y='Carbon_Price',data=single_scen,hue=main_remind.Scenario)
plt.legend(loc='lower left', bbox_to_anchor=(1,0),ncol=2)
#plt.yscale('log')

# %%
scen='SSP1-19-SPA1-V17'
single_scen=main_remind[main_remind.Region=='USA'].copy()
sns.lineplot(x='Year',y='PriceXTotalCDR',data=single_scen,hue=main_remind.Scenario)
plt.legend(loc='lower left', bbox_to_anchor=(1,0),ncol=2)
#plt.yscale('log')

# %%
scen='SSP1-19-SPA1-V17'
single_scen=main_remind[main_remind.Scenario==scen].copy()
sns.lineplot(x='Year',y='TOTAL_CDR',data=single_scen,hue='Region')
plt.legend(loc='lower left', bbox_to_anchor=(1,0),ncol=2)
#plt.yscale('log')

# %%
scen='SSP1-19-SPA1-V17'
single_scen=main_remind[main_remind.Scenario==scen].copy()
sns.lineplot(x='Year',y='PriceXTotalCDR',data=single_scen,hue='Region')
plt.legend(loc='lower left', bbox_to_anchor=(1,0),ncol=2)
#plt.yscale('log')

# %% [markdown]
# # DERIVE CUMULATIVE POPULATION and GDP
#
# ## Population
# - Derive historic population from World Bank Data up to 2015 (annual data)
# - Derive future populations from IAM (10 year interpolation)
# - Fill in between 2015 to 2020
#
# ## GDP
# - take GDP|MER [TO CHECK!], infill annual values

# %%
# CUMMULATIVE HISTORIC POPULATION

#reg='WEU'         # ??

#historic population model region specific

def cum_historic_pop_calc(model, hist_data, regions_names):
    cum_hist_pop=pd.DataFrame(index=regions_names,columns=['Cum_Hist_Pop'])

    for reg in hist_data.index:
        pop_reg_time=pop_data_hist.loc[regions_names[reg],np.arange(date_cumulative_beginning, end_historical_data+1).astype('str')]  # +1 to make the function go from 1990 to 2015
        cum_hist_pop.loc[reg,'Cum_Hist_Pop']=pop_reg_time.sum().sum()
    return cum_hist_pop

    # CHECK BETWEEN SUM OF COUNTRIES AND TOTAL WORLD POPULATION - MISMATCH DUE TO MISSING COUNTRIES IN REGIONAL CLASSIFICATION
    #print('Cum Pop sum over region', cum_hist_pop[cum_hist_pop.index!='World'].sum())
    #print('Cum Pop World', cum_hist_pop.loc['World'])
    #print(cum_hist_pop) #in millions 1990-2015


cum_hist_pop_remind = cum_historic_pop_calc(main_remind, cum_em_df_remind, regions_names_remind)
cum_hist_pop_image = cum_historic_pop_calc(main_image, cum_em_df_image, regions_names_image)
#cum_hist_pop_message = cum_historic_pop_calc(main_message, cum_em_df_message, regions_names_message)
#cum_hist_pop_strefler = cum_historic_pop_calc(main_strefler, cum_em_df_strefler, regions_names_remind)

#print(cum_hist_pop_remind)
#print(cum_hist_pop_image)
#print(cum_hist_pop_strefler)

# %%
# DERIVE CUMULATIVE POPULATION GOING FORWARD      -   Alternative way to do it (to use: remove hashtags, works only with data in 10 year steps)
  
def gdp_pop_calc(main_df, model):   
    #full_df['CUM_POP']=np.nan
    main_df['Population']=np.nan
    main_df['GDP']=np.nan
    main_df['Unit_Population'] = 'Mio'

    for reg,scen in itertools.product(main_df.Region.unique(),main_df.Scenario.unique()):  ## for IMAGE / REMIND
  #  for reg,scen in itertools.product(main_df.Region.unique(),['SSP1-19','LowEnergyDemand']):  ## MESSAGE
        # Get population from scenario and run
        pop_iam=model.loc[(model.Scenario==scen)&
            (model.Region==reg)&(model.Variable=='Population'),:].iloc[0,7:]

        main_df.loc[(main_df.Year==beginning_modelled_data)&
                (main_df.Scenario==scen)&
                (main_df.Region==reg),'Population']=pop_iam.loc[beginning_modelled_data]
        try:
            main_df.loc[(main_df.Year==beginning_modelled_data)&
            (main_df.Scenario==scen)&
            (main_df.Region==reg),'GDP']=model.loc[(model.Scenario==scen)&
                                (model.Region==reg)&(model.Variable=='GDP|PPP'),beginning_modelled_data].iloc[0]
        except:
            print(reg, scen)                        

        # DERIVE CUMULATIVE POPULATION
        # Fill in years between 2015 and 2020 
    #    add15_to_20=5*0.5*(pop_data_hist.loc[regions_names[reg],str(end_historical_data)].sum()
    #                       +pop_iam.loc[2020])

        # Add historic population
    #    add15_to_20+=cum_hist_pop.loc[reg]

    #    full_df.loc[(full_df.Year==beginning_modelled_data)&
    #            (full_df.Scenario==scen)&
    #            (full_df.Region==reg),'CUM_POP']=add15_to_20[0]

        # DERIVE CUMULATIVE POPULATION GOING FORWARD
        for year in years[1:]:
            main_df.loc[(main_df.Year==year)&
                (main_df.Scenario==scen)&
                (main_df.Region==reg),'Population']=pop_iam.loc[year]
            # 10 year steps but emissions in CO2/yr, interpolate linearly
    #        full_df.loc[(full_df.Year==year)&
    #            (full_df.Scenario==scen)&
    #            (full_df.Region==reg),'CUM_POP']=10*0.5*(pop_iam.loc[year-10]
     #                                                    +pop_iam.loc[year])+full_df.loc[
      #                                                                      (full_df.Year==year-10)&
       #                                                                     (full_df.Scenario==scen)&
        #                                                                   (full_df.Region==reg),'CUM_POP'].values
            # GDP
            main_df.loc[(main_df.Year==year)&
            (main_df.Scenario==scen)&
            
                        (main_df.Region==reg),'GDP']=model.loc[(model.Scenario==scen)&
                                                        (model.Region==reg)&
                                                       (model.Variable=='GDP|PPP'),year].iloc[0]

    return main_df

main_image = gdp_pop_calc(main_image, df_image)
main_remind = gdp_pop_calc(main_remind, df_remind)
#main_message = gdp_pop_calc(main_message, df_message)
#main_strefler = gdp_pop_calc(main_strefler, df_remind_strefler)

# %%
# cum_pop Calculation (works also with data that is not necessarily in 10year steps)

def cum_pop_calc(main_df, cum_hist_pop_data, regions_names):

    main_df['cumPopulation'] = 0

    for reg in main_df.Region.unique():
        mask = main_df.Region == reg
        full_reg = main_df.loc[mask,:]

        for scen in full_reg.Scenario.unique():
            mask_scen = full_reg.Scenario == scen
            full_scen = full_reg.loc[mask_scen,:]
            integral = integrate.cumtrapz(y = full_scen.Population, x = full_scen.Year, initial = 0)
            pop_in_2020 = full_scen.loc[(full_scen.Year == beginning_modelled_data), 'Population']
            pop_in_2020 = int(pop_in_2020)
            diff15_20 = 5*0.5*(pop_data_hist.loc[regions_names[reg], '2015'].sum() 
                               + full_scen.loc[(full_scen.Year == beginning_modelled_data), 'Population'])
            diff15_20+=cum_hist_pop_data.loc[reg].values

            integral += diff15_20.values
            full_reg.loc[mask_scen,'cumPopulation'] += integral

        main_df.loc[mask,'cumPopulation'] = full_reg.loc[:,'cumPopulation']

    return main_df
    
main_remind = cum_pop_calc(main_remind, cum_hist_pop_remind, regions_names_remind)
main_image = cum_pop_calc(main_image, cum_hist_pop_image, regions_names_image)
#main_message = cum_pop_calc(main_message, cum_hist_pop_message, regions_names_message)
#main_strefler = cum_pop_calc(main_strefler, cum_hist_pop_strefler, regions_names_remind)

# %%
def historic_2016(mdf, main_df): #mdf is the dataframe with historic emissions data, main_df is the model df

    main_df.loc[:,'2016_emissions'] = 0
    val2016 = mdf.loc[mdf.Year == '2016']

    for reg in main_df.Region.unique():
        rfilt = (main_df.Region == reg)
        val_reg = val2016.loc[(val2016.Country == reg), 'Value'].values
        for scen in main_df.Scenario.unique():
            sfilt = (main_df.Scenario == scen)
            for yr in main_df.Year.unique():
                yfilt = (main_df.Year == yr)
                main_df.loc[rfilt & sfilt & yfilt,'2016_emissions'] = val_reg
                
    return main_df

main_image = historic_2016(mdf_image, main_image)
main_remind = historic_2016(mdf_remind, main_remind)
#SLmain_message = historic_2016(mdf_message, main_message)

# %%
def change_from_historic(mdf, main_df): #mdf is the dataframe with historic emissions data, main_df is the model df

    main_df.loc[:,'em_change'] = 0

    for reg in main_df.Region.unique():
        rfilt = (main_df.Region == reg)
        for scen in main_df.Scenario.unique():
            sfilt = (main_df.Scenario == scen)
            for yr in main_df.Year.unique():
                yfilt = (main_df.Year == yr)
                main_df.loc[rfilt & sfilt & yfilt,'em_change'] = main_df.loc[rfilt & sfilt & yfilt, 'CO2_Emissions'] / main_df.loc[rfilt & sfilt & yfilt,'2016_emissions']
                
    return main_df

main_image = change_from_historic(mdf_image, main_image)
main_remind = change_from_historic(mdf_remind, main_remind)
#main_message = change_from_historic(mdf_message, main_message)

# %%
# EXCEL EXPORT

#def excel_export_calc(main_df, model_name):
#    main_df.to_excel(data_path + model_name + '/' + 'processed_output_inkl2015.xls'

main_image.to_excel(data_path + 'IMAGE_processed_output_FAO.xls')
main_remind.to_excel(data_path + 'REMIND_processed_output_FAO.xls')
#main_message.to_excel(data_path + 'MESSAGE_processed_output_FAO.xls')
#main_strefler.to_excel(data_path + 'STREFLER_processed_output_inkl2015.xls')

# %%
main_image.loc[main_image.Region == 'WAF']

# %%
#IMPORT EXCEL
main_remind=pd.read_excel(data_path+'REMIND_processed_output_FAO.xls')
main_image=pd.read_excel(data_path+'IMAGE_processed_output_FAO.xls')

# %%
rego = ['LAM', 'USA', 'CHN', 'RUS', 'EUR']
scen='SSP1-19-SPA1-V17'
single_scen=main_remind[(main_remind.Scenario==scen) &
                        (main_remind.Region.isin(rego))].copy()
sns.lineplot(x='Year',y='LANDCDR',data=single_scen,hue='Region')
plt.legend(loc='lower left', bbox_to_anchor=(1,0),ncol=2)

# %%
rego = ['BRA', 'USA', 'CHN', 'CAN']
scen='SSP1-19-SPA0-V17'
single_scen=main_image[(main_image.Scenario==scen)&
                   (main_image.Region.isin(rego))].copy()
scen='SSP1-19-SPA0-V17'
sns.lineplot(x='Year',y='LANDCDR',data=single_scen,hue='Region')
plt.legend(loc='lower left', bbox_to_anchor=(1,0),ncol=2)

# %%
plot_path = "/Users/Broccolee/Google Drive/Grad School/TU BERLIN/Negative Emissions & Carbon Markets/Plots/"

# %%
rego = ['LAM', 'USA', 'CHN', 'RUS', 'EUR']
scen='SSP1-19-SPA1-V17'
single_scen=main_remind[(main_remind.Scenario==scen) &
                        (main_remind.Region.isin(rego))].copy()
sns.lineplot(x='Year',y='GDP',data=single_scen, hue="Region", palette=['green','red','lightsalmon','skyblue','blue'], legend="full")
plt.legend(loc='lower left', bbox_to_anchor=(1,0),ncol=2)
plt.savefig(plot_path + 'GDP_per_region_RCP19.png', bbox_inches='tight')

# %%
rego = ['BRA', 'USA', 'CHN', 'RUS', 'WEU']
single_scen=main_image[(main_image.Scenario==scen)&
                   (main_image.Region.isin(rego))].copy()
scen='SSP1-19-SPA0-V17'
sns.lineplot(x='Year',y='GDP',data=single_scen,hue='Region')
plt.legend(loc='lower left', bbox_to_anchor=(1,0),ncol=2)

# %%
scen='SSP1-19-SPA1-V17'
rego = ['LAM', 'USA', 'CHN', 'RUS', 'EUR']
single_scen=main_remind[(main_remind.Scenario==scen)&(
    main_remind.Region.isin(rego))].copy()
# single_scen=single_scen.set_index('Year')
sns.lineplot(x='Year',y='cumPopulation',data=single_scen,hue='Region', palette=['green','red','lightsalmon','skyblue','blue'])
plt.legend(loc='lower left', bbox_to_anchor=(1,0),ncol=2)
plt.savefig(plot_path + 'cumPopulation_per_region_RCP19.png', bbox_inches='tight')

# %%
scen='SSP1-19-SPA0-V17'
single_scen=full_df[full_df.Scenario==scen].copy()
# single_scen=single_scen.set_index('Year')
sns.lineplot(x='Year',y='GDP',data=single_scen,hue='Region')
plt.legend(loc='lower left', bbox_to_anchor=(1,0),ncol=2)
plt.yscale('log')

# %%
scen = ['SSP1-19-SPA1-V17']
single_reg=main_remind[(main_remind.Scenario.isin(scen)) &
                        (main_remind.Region == 'World')].copy()
single_reg.loc[:,'TOTAL_CDR'] = single_reg.loc[:,'TOTAL_CDR']*-10**-3
single_reg.loc[:,'Total_GHG'] = single_reg.loc[:,'Total_GHG']*10**-3
single_reg.loc[:,'CO2_Emissions'] = single_reg.loc[:,'CO2_Emissions']*10**-3

rfilt = (mdf_remind.Country == 'World')
mdf_remind_world = mdf_remind.loc[(mdf_remind.Year >= '1990') & rfilt].copy()
mdf_remind_world.loc[:,'Value'] = mdf_remind_world.loc[:,'Value']*10**-3

# sns.lineplot(x = 'Year', y = 'Value', data = mdf_remind_world)

sns.lineplot(x='Year',y='TOTAL_CDR',data=single_reg, linewidth = 3, label = 'CDR')
sns.lineplot(x='Year', y='CO2_Emissions',data = single_reg, linewidth = 3, label = 'GHG emissions excluding CDR')
sns.lineplot(x='Year',y='Total_GHG',data=single_reg, linewidth = 3, color = 'black', label = 'Net GHG emissions', alpha = 0.3)
plt.fill_between(np.arange(2020,2110,10), single_reg["TOTAL_CDR"].values, alpha=0.5) 
plt.fill_between(np.arange(2020,2110,10), single_reg["CO2_Emissions"].values, alpha=0.5) 

# plt.line(x = np.arange(2020,2100,10), y = 0)
plt.axhline(0, color='black', linestyle='-', linewidth=1.5, alpha=0.5)
plt.ylabel('Emissions / removals (GtCO2)', fontsize = 14)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14, rotation = 45)
plt.xlabel("", fontsize = 14)

plt.legend(loc = 'lower left', bbox_to_anchor=(1,0),ncol=2)
# plt.legend(loc='upper right', fontsize = 14)
